# %% [markdown]
# You can order print and ebook versions of *Think Python 3e* from
# [Bookshop.org](https://bookshop.org/a/98697/9781098155438) and
# [Amazon](https://www.amazon.com/_/dp/1098155432?smid=ATVPDKIKX0DER&_encoding=UTF8&tag=oreilly20-20&_encoding=UTF8&tag=greenteapre01-20&linkCode=ur2&linkId=e2a529f94920295d27ec8a06e757dc7c&camp=1789&creative=9325).

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + str(local))
    return filename

download('https://github.com/AllenDowney/ThinkPython/raw/v3/thinkpython.py');
download('https://github.com/AllenDowney/ThinkPython/raw/v3/diagram.py');

import thinkpython
# Out:
# Downloaded thinkpython.py
# Downloaded diagram.py

# %% [markdown]
# # Text Analysis and Generation
#
# At this point we have covered Python's core data structures -- lists, dictionaries, and tuples -- and some algorithms that use them.
# In this chapter, we'll use them to explore text analysis and Markov generation:
#
# * Text analysis is a way to describe the statistical relationships between the words in a document, like the probability that one word is followed by another, and
#
# * Markov generation is a way to generate new text with words and phrases similar to the original text.
#
# These algorithms are similar to parts of a Large Language Model (LLM), which is the key component of a chatbot.
#
# We'll start by counting the number of times each word appears in a book.
# Then we'll look at pairs of words, and make a list of the words that can follow each word.
# We'll make a simple version of a Markov generator, and as an exercise, you'll have a chance to make a more general version.

# %% [markdown]
# ## Unique words
#
# As a first step toward text analysis, let's read a book -- *The Strange Case Of Dr. Jekyll And Mr. Hyde* by Robert Louis Stevenson -- and count the number of unique words.
# Instructions for downloading the book are in the notebook for this chapter.

# %% [markdown]
# The following cell downloads the book from Project Gutenberg.

# %%
download('https://www.gutenberg.org/cache/epub/43/pg43.txt');
# Out:
# Downloaded pg43.txt

# %% [markdown]
# The version available from Project Gutenberg includes information about the book at the beginning and license information at the end.
# We'll use `clean_file` from Chapter 8 to remove this material and write a "clean" file that contains only the text of the book.

# %%
def is_special_line(line):
    return line.strip().startswith('*** ')

# %%
def clean_file(input_file, output_file):
    reader = open(input_file, encoding='utf-8')
    writer = open(output_file, 'w')

    for line in reader:
        if is_special_line(line):
            break

    for line in reader:
        if is_special_line(line):
            break
        writer.write(line)

    reader.close()
    writer.close()

# %%
filename = 'dr_jekyll.txt'

# %%
clean_file('pg43.txt', filename)

# %% [markdown]
# We'll use a `for` loop to read lines from the file and `split` to divide the lines into words.
# Then, to keep track of unique words, we'll store each word as a key in a dictionary.

# %%
unique_words = {}
for line in open(filename):
    seq = line.split()
    for word in seq:
        unique_words[word] = 1

len(unique_words)
# Out:
# 6039

# %% [markdown]
# The length of the dictionary is the number of unique words -- about `6000` by this way of counting.
# But if we inspect them, we'll see that some are not valid words.
#
# For example, let's look at the longest words in `unique_words`.
# We can use `sorted` to sort the words, passing the `len` function as a keyword argument so the words are sorted by length.

# %%
sorted(unique_words, key=len)[-5:]
# Out:
# ['chocolate-coloured',
#  'superiors—behold!”',
#  'coolness—frightened',
#  'gentleman—something',
#  'pocket-handkerchief.']

# %% [markdown]
# The slice index, `[-5:]`, selects the last `5` elements of the sorted list, which are the longest words.
#
# The list includes some legitimately long words, like "circumscription", and some hyphenated words, like "chocolate-coloured".
# But some of the longest "words" are actually two words separated by a dash.
# And other words include punctuation like periods, exclamation points, and quotation marks.
#
# So, before we move on, let's deal with dashes and other punctuation.

# %% [markdown]
# ## Punctuation
#
# To identify the words in the text, we need to deal with two issues:
#
# * When a dash appears in a line, we should replace it with a space -- then when we use `split`, the words will be separated.
#
# * After splitting the words, we can use `strip` to remove punctuation.
#
# To handle the first issue, we can use the following function, which takes a string, replaces dashes with spaces, splits the string, and returns the resulting list.

# %%
def split_line(line):
    return line.replace('—', ' ').split()

# %% [markdown]
# Notice that `split_line` only replaces dashes, not hyphens.
# Here's an example.

# %%
split_line('coolness—frightened')
# Out:
# ['coolness', 'frightened']

# %% [markdown]
# Now, to remove punctuation from the beginning and end of each word, we can use `strip`, but we need a list of characters that are considered punctuation.
#
# Characters in Python strings are in Unicode, which is an international standard used to represent letters in nearly every alphabet, numbers, symbols, punctuation marks, and more.
# The `unicodedata` module provides a `category` function we can use to tell which characters are punctuation.
# Given a letter, it returns a string with information about what category the letter is in.

# %%
import unicodedata

unicodedata.category('A')
# Out:
# 'Lu'

# %% [markdown]
# The category string of `'A'` is `'Lu'` -- the `'L'` means it is a letter and the `'u'` means it is uppercase.
#
# The category string of `'.'` is `'Po'` -- the `'P'` means it is punctuation and the `'o'` means its subcategory is "other".

# %%
unicodedata.category('.')
# Out:
# 'Po'

# %% [markdown]
# We can find the punctuation marks in the book by checking for characters with categories that begin with `'P'`.
# The following loop stores the unique punctuation marks in a dictionary.

# %%
punc_marks = {}
for line in open(filename):
    for char in line:
        category = unicodedata.category(char)
        if category.startswith('P'):
            punc_marks[char] = 1

# %% [markdown]
# To make a list of punctuation marks, we can join the keys of the dictionary into a string.

# %%
punctuation = ''.join(punc_marks)
print(punctuation)
# Out:
# .’;,-“”:?—‘!()_

# %% [markdown]
# Now that we know which characters in the book are punctuation, we can write a function that takes a word, strips punctuation from the beginning and end, and converts it to lower case.

# %%
def clean_word(word):
    return word.strip(punctuation).lower()

# %% [markdown]
# Here's an example.

# %%
clean_word('“Behold!”')
# Out:
# 'behold'

# %% [markdown]
# Because `strip` removes characters from the beginning and end, it leaves hyphenated words alone.

# %%
clean_word('pocket-handkerchief')
# Out:
# 'pocket-handkerchief'

# %% [markdown]
# Now here's a loop that uses `split_line` and `clean_word` to identify the unique words in the book.

# %%
unique_words2 = {}
for line in open(filename):
    for word in split_line(line):
        word = clean_word(word)
        unique_words2[word] = 1

len(unique_words2)
# Out:
# 4003

# %% [markdown]
# With this stricter definition of what a word is, there are about 4000 unique words.
# And we can confirm that the list of longest words has been cleaned up.

# %%
sorted(unique_words2, key=len)[-5:]
# Out:
# ['circumscription',
#  'unimpressionable',
#  'fellow-creatures',
#  'chocolate-coloured',
#  'pocket-handkerchief']

# %% [markdown]
# Now let's see how many times each word is used.

# %% [markdown]
# ## Word frequencies
#
# The following loop computes the frequency of each unique word.

# %%
word_counter = {}
for line in open(filename):
    for word in split_line(line):
        word = clean_word(word)
        if word not in word_counter:
            word_counter[word] = 1
        else:
            word_counter[word] += 1

# %% [markdown]
# The first time we see a word, we initialize its frequency to `1`. If we see the same word again later, we increment its frequency.
#
# To see which words appear most often, we can use `items` to get the key-value pairs from `word_counter`, and sort them by the second element of the pair, which is the frequency.
# First we'll define a function that selects the second element.

# %%
def second_element(t):
    return t[1]

# %% [markdown]
# Now we can use `sorted` with two keyword arguments:
#
# * `key=second_element` means the items will be sorted according to the frequencies of the words.
#
# * `reverse=True` means the items will be sorted in reverse order, with the most frequent words first.

# %%
items = sorted(word_counter.items(), key=second_element, reverse=True)

# %% [markdown]
# Here are the five most frequent words.

# %%
for word, freq in items[:5]:
    print(freq, word, sep='\t')
# Out:
# 1614	the
# 972	and
# 941	of
# 640	to
# 640	i

# %% [markdown]
# In the next section, we'll encapsulate this loop in a function.
# And we'll use it to demonstrate a new feature -- optional parameters.

# %% [markdown]
# ## Optional parameters
#
# We've used built-in functions that take optional parameters.
# For example, `round` takes an optional parameters called `ndigits` that indicates how many decimal places to keep.

# %%
round(3.141592653589793, ndigits=3)
# Out:
# 3.142

# %% [markdown]
# But it's not just built-in functions -- we can write functions with optional parameters, too.
# For example, the following function takes two parameters, `word_counter` and `num`.

# %%
def print_most_common(word_counter, num=5):
    items = sorted(word_counter.items(), key=second_element, reverse=True)

    for word, freq in items[:num]:
        print(freq, word, sep='\t')

# %% [markdown]
# The second parameter looks like an assignment statement, but it's not -- it's an optional parameter.
#
# If you call this function with one argument, `num` gets the **default value**, which is `5`.

# %%
print_most_common(word_counter)
# Out:
# 1614	the
# 972	and
# 941	of
# 640	to
# 640	i

# %% [markdown]
# If you call this function with two arguments, the second argument gets assigned to `num` instead of the default value.

# %%
print_most_common(word_counter, 3)
# Out:
# 1614	the
# 972	and
# 941	of

# %% [markdown]
# In that case, we would say the optional argument **overrides** the default value.
#
# If a function has both required and optional parameters, all of the required parameters have to come first, followed by the optional ones.

# %%
# %%expect SyntaxError
#
# def bad_function(n=5, word_counter):
#     return None
# Out:
#   File "/tmp/ipykernel_11651/3116647453.py", line 1
#     def bad_function(n=5, word_counter):
#                           ^
# SyntaxError: parameter without a default follows parameter with a default

# %% [markdown]
# ## Dictionary subtraction
#
# Suppose we want to spell-check a book -- that is, find a list of words that might be misspelled.
# One way to do that is to find words in the book that don't appear in a list of valid words.
# In previous chapters, we've used a list of words that are considered valid in word games like Scrabble.
# Now we'll use this list to spell-check Robert Louis Stevenson.
#
# We can think of this problem as set subtraction -- that is, we want to find all the words from one set (the words in the book) that are not in the other (the words in the list).

# %% [markdown]
# The following cell downloads the word list.

# %%
download('https://raw.githubusercontent.com/AllenDowney/ThinkPython/v3/words.txt');
# Out:
# Downloaded words.txt

# %% [markdown]
# As we've done before, we can read the contents of `words.txt` and split it into a list of strings.

# %%
word_list = open('words.txt').read().split()

# %% [markdown]
# Then we'll store the words as keys in a dictionary so we can use the `in` operator to check quickly whether a word is valid.

# %%
valid_words = {}
for word in word_list:
    valid_words[word] = 1

# %% [markdown]
# Now, to identify words that appear in the book but not in the word list, we'll use `subtract`, which takes two dictionaries as parameters and returns a new dictionary that contains all the keys from one that are not in the other.

# %%
def subtract(d1, d2):
    res = {}
    for key in d1:
        if key not in d2:
            res[key] = d1[key]
    return res

# %% [markdown]
# Here's how we use it.

# %%
diff = subtract(word_counter, valid_words)

# %% [markdown]
# To get a sample of words that might be misspelled, we can print the most common words in `diff`.

# %%
print_most_common(diff)
# Out:
# 640	i
# 628	a
# 128	utterson
# 124	mr
# 98	hyde

# %% [markdown]
# The most common "misspelled" words are mostly names and a few single-letter words (Mr. Utterson is Dr. Jekyll's friend and lawyer).
#
# If we select words that only appear once, they are more likely to be actual misspellings.
# We can do that by looping through the items and making a list of words with frequency `1`.

# %%
singletons = []
for word, freq in diff.items():
    if freq == 1:
        singletons.append(word)

# %% [markdown]
# Here are the last few elements of the list.

# %%
singletons[-5:]
# Out:
# ['gesticulated', 'abjection', 'circumscription', 'reindue', 'fearstruck']

# %% [markdown]
# Most of them are valid words that are not in the word list.
# But `'reindue'` appears to be a misspelling of `'reinduce'`, so at least we found one legitimate error.

# %% [markdown]
# ## Random numbers
#
# As a step toward Markov text generation, next we'll choose a random sequence of words from `word_counter`.
# But first let's talk about randomness.
#
# Given the same inputs, most computer programs are **deterministic**, which means they generate the same outputs every time.
# Determinism is usually a good thing, since we expect the same calculation to yield the same result.
# For some applications, though, we want the computer to be unpredictable.
# Games are one example, but there are more.
#
# Making a program truly nondeterministic turns out to be difficult, but there are ways to fake it.
# One is to use algorithms that generate **pseudorandom** numbers.
# Pseudorandom numbers are not truly random because they are generated by a deterministic computation, but just by looking at the numbers it is all but impossible to distinguish them from random.
#
# The `random` module provides functions that generate pseudorandom numbers -- which I will simply call "random" from here on.
# We can import it like this.

# %%
import random

# %%
# this cell initializes the random number generator so it
# generates the same sequence each time the notebook runs.

random.seed(4)

# %% [markdown]
# The `random` module provides a function called `choice` that chooses an element from a list at random, with every element having the same probability of being chosen.

# %%
t = [1, 2, 3]
random.choice(t)
# Out:
# 1

# %% [markdown]
# If you call the function again, you might get the same element again, or a different one.

# %%
random.choice(t)
# Out:
# 2

# %% [markdown]
# In the long run, we expect to get every element about the same number of times.
#
# If you use `choice` with a dictionary, you get a `KeyError`.

# %%
# %%expect KeyError
#
# random.choice(word_counter)
# Out:
# KeyError: 422

# %% [markdown]
# To choose a random key, you have to put the keys in a list and then call `choice`.

# %%
words = list(word_counter)
random.choice(words)
# Out:
# 'self-defence'

# %% [markdown]
# If we generate a random sequence of words, it doesn't make much sense.

# %%
for i in range(6):
    word = random.choice(words)
    print(word, end=' ')
# Out:
# ill-contained upright apocryphal nor busy spoke

# %% [markdown]
# Part of the problem is that we are not taking into account that some words are more common than others.
# The results will be better if we choose words with different "weights", so that some are chosen more often than others.
#
# If we use the values from `word_counter` as weights, each word is chosen with a probability that depends on its frequency.

# %%
weights = word_counter.values()

# %% [markdown]
# The `random` module provides another function called `choices` that takes weights as an optional argument.

# %%
random.choices(words, weights=weights)
# Out:
# ['than']

# %% [markdown]
# And it takes another optional argument, `k`, that specifies the number of words to select.

# %%
random_words = random.choices(words, weights=weights, k=6)
random_words
# Out:
# ['reach', 'streets', 'edward', 'a', 'said', 'to']

# %% [markdown]
# The result is a list of strings that we can join into something that's looks more like a sentence.

# %%
' '.join(random_words)
# Out:
# 'reach streets edward a said to'

# %% [markdown]
# If you choose words from the book at random, you get a sense of the vocabulary, but a series of random words seldom makes sense because there is no relationship between successive words.
# For example, in a real sentence you expect an article like "the" to be followed by an adjective or a noun, and probably not a verb or adverb.
# So the next step is to look at these relationships between words.

# %% [markdown]
# ## Bigrams
#
# Instead of looking at one word at a time, now we'll look at sequences of two words, which are called **bigrams**.
# A sequence of three words is called a **trigram**, and a sequence with some unspecified number of words is called an **n-gram**.
#
# Let's write a program that finds all of the bigrams in the book and the number of times each one appears.
# To store the results, we'll use a dictionary where
#
# * The keys are tuples of strings that represent bigrams, and
#
# * The values are integers that represent frequencies.
#
# Let's call it `bigram_counter`.

# %%
bigram_counter = {}

# %% [markdown]
# The following function takes a list of two strings as a parameter.
# First it makes a tuple of the two strings, which can be used as a key in a dictionary.
# Then it adds the key to `bigram_counter`, if it doesn't exist, or increments the frequency if it does.

# %%
def count_bigram(bigram):
    key = tuple(bigram)
    if key not in bigram_counter:
        bigram_counter[key] = 1
    else:
        bigram_counter[key] += 1

# %% [markdown]
# As we go through the book, we have to keep track of each pair of consecutive words.
# So if we see the sequence "man is not truly one", we would add the bigrams "man is", "is not", "not truly", and so on.
#
# To keep track of these bigrams, we'll use a list called `window`, because it is like a window that slides over the pages of the book, showing only two words at a time.
# Initially, `window` is empty.

# %%
window = []

# %% [markdown]
# We'll use the following function to process the words one at a time.

# %%
def process_word(word):
    window.append(word)

    if len(window) == 2:
        count_bigram(window)
        window.pop(0)

# %% [markdown]
# The first time this function is called, it appends the given word to `window`.
# Since there is only one word in the window, we don't have a bigram yet, so the function ends.
#
# The second time it's called -- and every time thereafter -- it appends a second word to `window`.
# Since there are two words in the window, it calls `count_bigram` to keep track of how many times each bigram appears.
# Then it uses `pop` to remove the first word from the window.
#
# The following program loops through the words in the book and processes them one at a time.

# %%
for line in open(filename):
    for word in split_line(line):
        word = clean_word(word)
        process_word(word)

# %% [markdown]
# The result is a dictionary that maps from each bigram to the number of times it appears.
# We can use `print_most_common` to see the most common bigrams.

# %%
print_most_common(bigram_counter)
# Out:
# 178	('of', 'the')
# 139	('in', 'the')
# 94	('it', 'was')
# 80	('and', 'the')
# 73	('to', 'the')

# %% [markdown]
# Looking at these results, we can get a sense of which pairs of words are most likely to appear together.
# We can also use the results to generate random text, like this.

# %%
random.seed(0)

# %%
bigrams = list(bigram_counter)
weights = bigram_counter.values()
random_bigrams = random.choices(bigrams, weights=weights, k=6)

# %% [markdown]
# `bigrams` is a list of the bigrams that appear in the books.
# `weights` is a list of their frequencies, so `random_bigrams` is a sample where the probability a bigram is selected is proportional to its frequency.
#
# Here are the results.

# %%
for pair in random_bigrams:
    print(' '.join(pair), end=' ')
# Out:
# begun to after this well hosts is if or above the laboratory

# %% [markdown]
# This way of generating text is better than choosing random words, but still doesn't make a lot of sense.

# %% [markdown]
# ## Markov analysis
#
# We can do better with Markov chain text analysis, which computes, for each word in a text, the list of words that come next.
# As an example, we'll analyze these lyrics from the Monty Python song *Eric, the Half a Bee*:

# %%
song = """
Half a bee, philosophically,
Must, ipso facto, half not be.
But half the bee has got to be
Vis a vis, its entity. D'you see?
"""

# %% [markdown]
# To store the results, we'll use a dictionary that maps from each word to the list of words that follow it.

# %%
successor_map = {}

# %% [markdown]
# As an example, let's start with the first two words of the song.

# %%
first = 'half'
second = 'a'

# %% [markdown]
# If the first word is not in `successor_map`, we have to add a new item that maps from the first word to a list containing the second word.

# %%
successor_map[first] = [second]
successor_map
# Out:
# {'half': ['a']}

# %% [markdown]
# If the first word is already in the dictionary, we can look it up to get the list of successors we've seen so far, and append the new one.

# %%
first = 'half'
second = 'not'

successor_map[first].append(second)
successor_map
# Out:
# {'half': ['a', 'not']}

# %% [markdown]
# The following function encapsulates these steps.

# %%
def add_bigram(bigram):
    first, second = bigram

    if first not in successor_map:
        successor_map[first] = [second]
    else:
        successor_map[first].append(second)

# %% [markdown]
# If the same bigram appears more that once, the second word is added to the list more than once.
# In this way, `successor_map` keeps track of how many times each successor appears.
#
# As we did in the previous section, we'll use a list called `window` to store pairs of consecutive words.
# And we'll use the following function to process the words one at a time.

# %%
def process_word_bigram(word):
    window.append(word)

    if len(window) == 2:
        add_bigram(window)
        window.pop(0)

# %% [markdown]
# Here's how we use it to process the words in the song.

# %%
successor_map = {}
window = []

for word in song.split():
    word = clean_word(word)
    process_word_bigram(word)

# %% [markdown]
# And here are the results.

# %%
successor_map
# Out:
# {'half': ['a', 'not', 'the'],
#  'a': ['bee', 'vis'],
#  'bee': ['philosophically', 'has'],
#  'philosophically': ['must'],
#  'must': ['ipso'],
#  'ipso': ['facto'],
#  'facto': ['half'],
#  'not': ['be'],
#  'be': ['but', 'vis'],
#  'but': ['half'],
#  'the': ['bee'],
#  'has': ['got'],
#  'got': ['to'],
#  'to': ['be'],
#  'vis': ['a', 'its'],
#  'its': ['entity'],
#  'entity': ["d'you"],
#  "d'you": ['see']}

# %% [markdown]
# The word `'half'` can be followed by `'a'`, `'not'`, or `'the'`.
# The word `'a'` can be followed by `'bee'` or `'vis'`.
# Most of the other words appear only once, so they are followed by only a single word.
#
# Now let's analyze the book.

# %%
successor_map = {}
window = []

for line in open(filename):
    for word in split_line(line):
        word = clean_word(word)
        process_word_bigram(word)

# %% [markdown]
# We can look up any word and find the words that can follow it.

# %%
# I used this cell to find a predecessor with a good number of possible successors
# and at least one repeated word.

def has_duplicates(t):
    return len(set(t)) < len(t)

for key, value in successor_map.items():
    if len(value) == 7 and has_duplicates(value):
        print(key, value)
# Out:
# story ['of', 'of', 'indeed', 'but', 'for', 'of', 'that']
# incident ['of', 'of', 'at', 'of', 'of', 'at', 'this']
# lanyon’s ['narrative', 'there', 'face', 'manner', 'narrative', 'the', 'condemnation']
# common ['it', 'interest', 'friends', 'friends', 'observers', 'but', 'quarry']
# relief ['the', 'to', 'when', 'that', 'that', 'of', 'it']
# appearance ['of', 'well', 'something', 'he', 'amply', 'of', 'which']
# going ['east', 'in', 'to', 'to', 'up', 'to', 'of']
# till ['at', 'the', 'i', 'yesterday', 'the', 'that', 'weariness']
# walk ['and', 'into', 'with', 'all', 'steadfastly', 'attired', 'with']
# sounds ['nothing', 'carried', 'out', 'the', 'of', 'of', 'with']
# really ['like', 'damnable', 'can', 'a', 'a', 'not', 'be']
# does ['not', 'not', 'indeed', 'not', 'the', 'not', 'not']
# reply ['i', 'but', 'whose', 'i', 'some', 'that’s', 'i']
# continued ['mr', 'the', 'the', 'the', 'the', 'poole', 'utterson']
# seems ['scarcely', 'hardly', 'to', 'she', 'much', 'he', 'to']
# walked ['on', 'over', 'some', 'was', 'on', 'with', 'fast']
# that’s ['a', 'it', 'talking', 'very', 'not', 'such', 'not']
# although ['i', 'a', 'it', 'the', 'we', 'they', 'i']
# until ['the', 'the', 'they', 'they', 'the', 'to-morrow', 'i']
# disappearance ['or', 'the', 'of', 'of', 'here', 'and', 'but']
# step ['into', 'or', 'back', 'natural', 'into', 'of', 'leaping']
# wish ['the', 'you', 'to', 'you', 'to', 'i', 'to']
# aware ['of', 'of', 'of', 'that', 'jekyll’s', 'that', 'of']
# thank ['you', 'you', 'you', 'you', 'you', 'god', 'you']
# maid ['servant', 'described', 'fainted', 'had', 'calls', 'had', 'lifted']
# besides ['were', 'was', 'for', 'a', 'with', 'with', 'which']
# observed ['the', 'utterson', 'with', 'the', 'that', 'that', 'that']
# among ['other', 'the', 'the', 'the', 'my', 'my', 'temptations']

# %%
successor_map['going']
# Out:
# ['east', 'in', 'to', 'to', 'up', 'to', 'of']

# %% [markdown]
# In this list of successors, notice that the word `'to'` appears three times -- the other successors only appear once.

# %% [markdown]
# ## Generating text
#
# We can use the results from the previous section to generate new text with the same relationships between consecutive words as in the original.
# Here's how it works:
#
# * Starting with any word that appears in the text, we look up its possible successors and choose one at random.
#
# * Then, using the chosen word, we look up its possible successors, and choose one at random.
#
# We can repeat this process to generate as many words as we want.
# As an example, let's start with the word `'although'`.
# Here are the words that can follow it.

# %%
word = 'although'
successors = successor_map[word]
successors
# Out:
# ['i', 'a', 'it', 'the', 'we', 'they', 'i']

# %%
H# this cell initializes the random number generator so it
# starts at the same point in the sequence each time this
# notebook runs.

random.seed(2)

# %% [markdown]
# We can use `choice` to choose from the list with equal probability.

# %%
word = random.choice(successors)
word
# Out:
# 'i'

# %% [markdown]
# If the same word appears more than once in the list, it is more likely to be selected.
#
# Repeating these steps, we can use the following loop to generate a longer series.

# %%
for i in range(10):
    successors = successor_map[word]
    word = random.choice(successors)
    print(word, end=' ')
# Out:
# he had thus it was written in possession of childhood

# %% [markdown]
# The result sounds more like a real sentence, but it still doesn't make much sense.
#
# We can do better using more than one word as a key in `successor_map`.
# For example, we can make a dictionary that maps from each bigram -- or trigram -- to the list of words that come next.
# As an exercise, you'll have a chance to implement this analysis and see what the results look like.

# %% [markdown]
# ## Debugging
#
# At this point we are writing more substantial programs, and you might find that you are spending more time debugging.
# If you are stuck on a difficult bug, here are a few things to try:
#
# * Reading: Examine your code, read it back to yourself, and check that it says what you meant to say.
#
# * Running: Experiment by making changes and running different versions. Often if you display the right thing at the right place in the program, the problem becomes obvious, but sometimes you have to build scaffolding.
#
# * Ruminating: Take some time to think! What kind of error is it: syntax, runtime,
#     or semantic? What information can you get from the error messages,
#     or from the output of the program? What kind of error could cause
#     the problem you're seeing? What did you change last, before the
#     problem appeared?
#
# * Rubberducking: If you explain the problem to someone else, you sometimes find the
#     answer before you finish asking the question. Often you don't need
#     the other person; you could just talk to a rubber duck. And that's
#     the origin of the well-known strategy called **rubber duck
#     debugging**. I am not making this up -- see
#     <https://en.wikipedia.org/wiki/Rubber_duck_debugging>.
#
# * Retreating: At some point, the best thing to do is back up -- undoing recent
#     changes -- until you get to a program that works. Then you can start rebuilding.
#
# * Resting: If you give your brain a break, sometime it will find the problem for you.

# %% [markdown]
# Beginning programmers sometimes get stuck on one of these activities and forget the others. Each activity comes with its own failure mode.
#
# For example, reading your code works if the problem is a typographical error, but not if the problem is a conceptual misunderstanding.
# If you don't understand what your program does, you can read it 100 times and never see the error, because the error is in your head.
#
# Running experiments can work, especially if you run small, simple tests.
# But if you run experiments without thinking or reading your code, it can take a long time to figure out what's happening.
#
# You have to take time to think. Debugging is like an experimental science. You should have at least one hypothesis about what the problem is. If there are two or more possibilities, try to think of a test that would eliminate one of them.

# %% [markdown]
# But even the best debugging techniques will fail if there are too many
# errors, or if the code you are trying to fix is too big and complicated.
# Sometimes the best option is to retreat, simplifying the program until
# you get back to something that works.
#
# Beginning programmers are often reluctant to retreat because they can't
# stand to delete a line of code (even if it's wrong). If it makes you
# feel better, copy your program into another file before you start
# stripping it down. Then you can copy the pieces back one at a time.
#
# Finding a hard bug requires reading, running, ruminating, retreating, and sometimes resting.
# If you get stuck on one of these activities, try the others.

# %% [markdown]
# ## Glossary
#
# **default value:**
# The value assigned to a parameter if no argument is provided.
#
# **override:**
#  To replace a default value with an argument.
#
# **deterministic:**
#  A deterministic program does the same thing each time it runs, given the same inputs.
#
# **pseudorandom:**
#  A pseudorandom sequence of numbers appears to be random, but is generated by a deterministic program.
#
# **bigram:**
# A sequence of two elements, often words.
#
# **trigram:**
# A sequence of three elements.
#
# **n-gram:**
# A sequence of an unspecified number of elements.
#
# **rubber duck debugging:**
# A way of debugging by explaining a problem aloud to an inanimate object.

# %% [markdown]
# ## Exercises

# %%
# This cell tells Jupyter to provide detailed debugging information
# when a runtime error occurs. Run it before working on the exercises.

# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %% [markdown]
# ### Ask a virtual assistant
#
# In `add_bigram`, the `if` statement creates a new list or appends an element to an existing list, depending on whether the key is already in the dictionary.

# %%
def add_bigram(bigram):
    first, second = bigram

    # Using setdefault to achieve the same logic more concisely
    # If 'first' is not in successor_map, it inserts successor_map[first] = []
    # and returns the empty list. Then 'second' is appended to it.
    # If 'first' is already in successor_map, it returns the existing list,
    # and 'second' is appended to it.
    successor_map.setdefault(first, []).append(second)

# %% [markdown]
# Dictionaries provide a method called `setdefault` that we can use to do the same thing more concisely.
# Ask a virtual assistant how it works, or copy `add_bigram` into a virtual assistant and ask "Can you rewrite this using `setdefault`?"
#
# In this chapter we implemented Markov chain text analysis and generation.
# If you are curious, you can ask a virtual assistant for more information on the topic.
# One of the things you might learn is that virtual assistants use algorithms that are similar in many ways -- but also different in important ways.
# Ask a VA, "What are the differences between large language models like GPT and Markov chain text analysis?"

# %% [markdown]
# ### Exercise
#
# Write a function that counts the number of times each trigram (sequence of three words) appears.
# If you test your function with the text of _Dr. Jekyll and Mr. Hyde_, you should find that the most common trigram is "said the lawyer".
#
# Hint: Write a function called `count_trigram` that is similar to `count_bigram`. Then write a function called `process_word_trigram` that is similar to `process_word_bigram`.

# %%
def add_trigram(trigram):
    first, second, third = trigram

    # Using setdefault to achieve the same logic more concisely.
    # If 'first' is not in successor_map, it inserts successor_map[first] = []
    # and returns the empty list. Then (second, third) is appended to it.
    # If 'first' is already in successor_map, it returns the existing list,
    # and (second, third) is appended to it.
    trigram_counter.setdefault(first, []).append((second, third))

# %%
def count_trigram(trigram):
    key = tuple(trigram)
    if key not in trigram_counter:
        trigram_counter[key] = 1
    else:
        trigram_counter[key] += 1

# %%
def process_word_trigram(word):
    window.append(word)

    if len(window) == 3:
        count_trigram(window)
        window.pop(0)

# %% [markdown]
# You can use the following loop to read the book and process the words.

# %%
trigram_counter = {}
window = []

for line in open(filename):
    for word in split_line(line):
        word = clean_word(word)
        process_word_trigram(word)

# %%
def process_word_trigram(word):
    window.append(word)

    if len(window) == 3:
        count_trigram(window)
        window.pop(0)

# %% [markdown]
# Then use `print_most_common` to find the most common trigrams in the book.

# %%
print_most_common(trigram_counter)
# Out:
# 20	('said', 'the', 'lawyer')
# 16	('said', 'mr', 'utterson')
# 15	('of', 'edward', 'hyde')
# 13	('the', 'name', 'of')
# 11	('it', 'was', 'a')

# %% [markdown]
# ### Exercise
#
# Now let's implement Markov chain text analysis with a mapping from each bigram to a list of possible successors.
#
# Starting with `add_bigram`, write a function called `add_trigram` that takes a list of three words and either adds or updates an item in `successor_map`, using the first two words as the key and the third word as a possible successor.

# %%
def add_trigram(trigram):
    first, second, third = trigram

    successor_map.setdefault((first, second), []).append(third)


def add_bigram(bigram):
    first, second = bigram

    # Using setdefault to achieve the same logic more concisely
    # If 'first' is not in successor_map, it inserts successor_map[first] = []
    # and returns the empty list. Then 'second' is appended to it.
    # If 'first' is already in successor_map, it returns the existing list,
    # and 'second' is appended to it.
    successor_map.setdefault(first, []).append(second)

# %% [markdown]
# Here's a version of `process_word_trigram` that calls `add_trigram`.

# %%
def process_word_trigram(word):
    window.append(word)

    if len(window) == 3:
        add_trigram(window)
        window.pop(0)

# %% [markdown]
# You can use the following loop to test your function with the lyrics of "Eric, the Half a Bee".

# %%
successor_map = {}
window = []

for string in song.split():
    word = string.strip(punctuation).lower()
    process_word_trigram(word)

# %% [markdown]
# If your function works as intended, the predecessor `('half', 'a')` should map to a list with the single element `'bee'`.
# In fact, as it happens, each bigram in this song appear only once, so all of the values in `successor_map` have a single element.

# %%
successor_map
# Out:
# {('the', 'strange'): ['case', 'clauses', 'immunities'],
#  ('strange', 'case'): ['of'],
#  ('case', 'of'): ['dr',
#   'the',
#   'dr',
#   'his',
#   'death',
#   'disappearance',
#   'cerebral'],
#  ('of', 'dr'): ['jekyll',
#   'lanyon',
#   'jekyll’s',
#   'jekyll’s',
#   'fell',
#   'jekyll',
#   'lanyon',
#   'jekyll',
#   'henry',
#   'jekyll'],
#  ('dr', 'jekyll'): ['and',
#   'was',
#   'he',
#   'at',
#   'was',
#   'is',
#   'was',
#   'was',
#   'grew',
#   'looking',
#   'whom',
#   'sir',
#   'he',
#   'he',
#   'what',
#   'come',
#   'to',
#   'presents',
#   'god',
#   'and',
#   'i',
#   'i',
#   'had',
#   'then'],
#  ('jekyll', 'and'): ['mr', 'even', 'it', 'certainly'],
#  ('and', 'mr'): ['hyde', 'utterson', 'enfield'],
#  ('mr', 'hyde'): ['by',
#   'dr',
#   'that',
#   'that',
#   'if',
#   'he',
#   'i',
#   'shrank',
#   'blowing',
#   'appeared',
#   'it',
#   'a',
#   'with',
#   'had',
#   'was',
#   'go',
#   'has',
#   'asked',
#   'i',
#   'who',
#   'broke',
#   'a',
#   'had',
#   'had',
#   'had',
#   'now',
#   'i',
#   'why',
#   'yes',
#   'ay',
#   'whom',
#   'at'],
#  ('hyde', 'by'): ['robert'],
#  ('by', 'robert'): ['louis'],
#  ('robert', 'louis'): ['stevenson'],
#  ('louis', 'stevenson'): ['contents'],
#  ('stevenson', 'contents'): ['story'],
#  ('contents', 'story'): ['of'],
#  ('story', 'of'): ['the', 'the', 'dr'],
#  ('of', 'the'): ['door',
#   'letter',
#   'case',
#   'door',
#   'after-dinner',
#   'passenger',
#   'by-street',
#   'entry',
#   'world',
#   'thing',
#   'question',
#   'points',
#   'night',
#   'proprieties',
#   'capers',
#   'cheque',
#   'style',
#   'day',
#   'name',
#   'way',
#   'other',
#   'neighbouring',
#   'decease',
#   'doctor’s',
#   'sane',
#   'shifting',
#   'man',
#   'man',
#   'morning',
#   'church',
#   'night',
#   'great',
#   'figure',
#   'bed',
#   'real',
#   'will',
#   'unimpressionable',
#   'fogged',
#   'low',
#   'houses',
#   'roadway',
#   'approach',
#   'city',
#   'court',
#   'street',
#   'breath',
#   'will',
#   'address',
#   'firelight',
#   'shadow',
#   'house',
#   'will',
#   'will',
#   'fire',
#   'victim',
#   'night',
#   'world',
#   'lane',
#   'season',
#   'gloomiest',
#   'law',
#   'house',
#   'fire',
#   'stick',
#   'servant',
#   'letter',
#   'block',
#   'garden',
#   'lawyer',
#   'scandal',
#   'town’s',
#   'ken',
#   'police',
#   'man’s',
#   'hatred',
#   'murder',
#   'host',
#   'mind',
#   'man',
#   'open',
#   'door',
#   'three',
#   'two',
#   'floor',
#   'relief',
#   'most',
#   'pavement',
#   'biting',
#   'servants',
#   'stair',
#   'cabinet',
#   'same',
#   'pen',
#   'old',
#   'room',
#   'same',
#   'murder',
#   'candle',
#   'theatre',
#   'night',
#   'night',
#   'door',
#   'doctor’s',
#   'building',
#   'surgeon',
#   'uselessness',
#   'corridor',
#   'cabinet',
#   'chamber',
#   'presses',
#   'name',
#   'theatre',
#   'service',
#   'day',
#   'dispensing',
#   'wrappers',
#   'portico',
#   'square',
#   'consulting',
#   'pulse',
#   'symptoms',
#   'coat',
#   'creature',
#   'hour',
#   'hysteria',
#   'contents',
#   'red',
#   'powders',
#   'soul',
#   'day',
#   'land',
#   'case',
#   'respect',
#   'wise',
#   'most',
#   'perennial',
#   'two',
#   'separation',
#   'powers',
#   'spirit',
#   'bonds',
#   'soul',
#   'day',
#   'one',
#   'other',
#   'spirit',
#   'flesh',
#   'prisonhouse',
#   'noted',
#   'infamy',
#   'bed',
#   'mahogany',
#   'drug',
#   'avenger',
#   'evening',
#   'scaffold',
#   'last',
#   'bonds',
#   'moment',
#   'presses',
#   'will',
#   'city',
#   'nocturnal',
#   'gallows',
#   'day',
#   'brute',
#   'day',
#   'air',
#   'drug',
#   'day',
#   'medicine',
#   'phenomena',
#   'pit',
#   'gallows',
#   'salt',
#   'first',
#   'last',
#   'old'],
#  ('the', 'door'): ['search',
#   'mr',
#   'which',
#   'whipped',
#   'in',
#   'said',
#   'to',
#   'of',
#   'in',
#   'crossing',
#   'and',
#   'of',
#   'is',
#   'she',
#   'and',
#   'was',
#   'of',
#   'both',
#   'was',
#   'the',
#   'poole',
#   'fell',
#   'on',
#   'they',
#   'in',
#   'of',
#   'and',
#   'of',
#   'was',
#   'stood',
#   'i',
#   'and',
#   'by'],
#  ('door', 'search'): ['for'],
#  ('search', 'for'): ['mr', 'mr'],
#  ('for', 'mr'): ['hyde', 'hyde', 'utterson', 'utterson', 'hyde', 'utterson'],
#  ('hyde', 'dr'): ['jekyll'],
#  ('jekyll', 'was'): ['quite',
#   'gone',
#   'quite',
#   'no',
#   'no',
#   'to',
#   'now',
#   'of',
#   'now'],
#  ('was', 'quite'): ['at', 'easy', 'at', 'gone'],
#  ('quite', 'at'): ['ease', 'ease'],
#  ('at', 'ease'): ['the', 'a'],
#  ('ease', 'the'): ['carew'],
#  ('the', 'carew'): ['murder', 'murder'],
#  ('carew', 'murder'): ['case', 'case'],
#  ('murder', 'case'): ['incident', 'nearly'],
#  ('case', 'incident'): ['of'],
#  ('incident', 'of'): ['the', 'dr', 'the', 'dr'],
#  ('the', 'letter'): ['incident', 'it', 'the', 'was', 'had', 'had', 'ran'],
#  ('letter', 'incident'): ['of'],
#  ('dr', 'lanyon'): ['incident', 'had', 'sat', 'but', 'time', 'took', 'he'],
#  ('lanyon', 'incident'): ['at'],
#  ('incident', 'at'): ['the', 'the'],
#  ('at', 'the'): ['window',
#   'high',
#   'best',
#   'end',
#   'corner',
#   'problem',
#   'door',
#   'horror',
#   'name',
#   'companion',
#   'bank',
#   'bottom',
#   'further',
#   'best',
#   'doctor’s',
#   'change',
#   'window',
#   'windows',
#   'sight',
#   'far',
#   'time',
#   'summons',
#   'laboratory',
#   'dead',
#   'word',
#   'paper',
#   'dead',
#   'top',
#   'door',
#   'bare',
#   'other',
#   'summons',
#   'sight',
#   'time',
#   'acuteness',
#   'instance',
#   'same',
#   'table',
#   'root',
#   'furtherance',
#   'least',
#   'hour',
#   'first',
#   'mirror',
#   'notion',
#   'time',
#   'sight',
#   'damned',
#   'very',
#   'inn',
#   'mere',
#   'last'],
#  ('the', 'window'): ['the', 'and', 'it', 'was'],
#  ('window', 'the'): ['last'],
#  ('the', 'last'): ['night',
#   'reputable',
#   'good',
#   'you',
#   'i',
#   'time',
#   'two',
#   'night',
#   'of',
#   'ingredient',
#   'months',
#   'year',
#   'calamity',
#   'of',
#   'time',
#   'moment'],
#  ('last', 'night'): ['dr', 'mr'],
#  ('night', 'dr'): ['lanyon’s'],
#  ('dr', 'lanyon’s'): ['narrative', 'there', 'narrative'],
#  ('lanyon’s', 'narrative'): ['henry', 'on'],
#  ('narrative', 'henry'): ['jekyll’s'],
#  ('henry', 'jekyll’s'): ['full', 'shoes', 'favourite', 'full'],
#  ('jekyll’s', 'full'): ['statement', 'statement'],
#  ('full', 'statement'): ['of', 'of'],
#  ('statement', 'of'): ['the', 'the'],
#  ('the', 'case'): ['story', 'i'],
#  ('case', 'story'): ['of'],
#  ('door', 'mr'): ['utterson', 'utterson'],
#  ('mr', 'utterson'): ['the',
#   'for',
#   'with',
#   'i',
#   'asking',
#   'no',
#   'that’s',
#   'what',
#   'again',
#   'sighed',
#   'came',
#   'though',
#   'he',
#   'they',
#   'began',
#   'had',
#   'stepped',
#   'of',
#   'will',
#   'it',
#   'can',
#   'common',
#   'that',
#   'regarded',
#   'stopped',
#   'said',
#   'sir',
#   'and',
#   'so',
#   'a',
#   'this',
#   'had',
#   'reflected',
#   'beheld',
#   'and',
#   'i',
#   'found',
#   'was',
#   'as',
#   'might',
#   'only',
#   'struggled',
#   'alone',
#   'began',
#   'and',
#   'was',
#   'at',
#   'but',
#   'was',
#   'said',
#   'sir',
#   'thought',
#   'the',
#   'ran',
#   'to',
#   'sir',
#   'back',
#   'in',
#   'that',
#   'biting',
#   'you',
#   'poole',
#   'and',
#   'well',
#   'but',
#   'that’s',
#   'if',
#   'quite',
#   'i’m',
#   'and',
#   'the'],
#  ('utterson', 'the'): ['lawyer', 'housemaid', 'lawyer'],
#  ('the', 'lawyer'): ['was',
#   'were',
#   'but',
#   'there’s',
#   'i',
#   'led',
#   'carried',
#   'all',
#   'was',
#   'looking',
#   'in',
#   'i',
#   'mr',
#   'he',
#   'stood',
#   'with',
#   'i',
#   'and',
#   'set',
#   'scared',
#   'i',
#   'i',
#   'the',
#   'and',
#   'had',
#   'carew',
#   'listened',
#   'no',
#   'liked',
#   'and',
#   'stopped',
#   'melted',
#   'just',
#   'the',
#   'i',
#   'dreaded',
#   'you',
#   'good-naturedly',
#   'now',
#   'be',
#   'in',
#   'i',
#   'a',
#   'thereupon',
#   'peevishly',
#   'to',
#   'very',
#   'bending',
#   'i',
#   'if',
#   'and',
#   'took',
#   'i',
#   'my',
#   'this',
#   'looked',
#   'conscious',
#   'use',
#   'let',
#   'in',
#   'unsealed',
#   'with',
#   'cried',
#   'solemnly',
#   'put'],
#  ('lawyer', 'was'): ['a', 'to'],
#  ('was', 'a'): ['man',
#   'nut',
#   'name',
#   'forgery',
#   'fellow',
#   'man',
#   'hearty',
#   'night',
#   'fine',
#   'square',
#   'pet',
#   'shudder',
#   'large',
#   'letter',
#   'man',
#   'pause',
#   'back',
#   'wild',
#   'will',
#   'brief',
#   'third',
#   'good',
#   'handy',
#   'policeman',
#   'certain',
#   'being',
#   'man',
#   'fine',
#   'creature',
#   'thing'],
#  ('a', 'man'): ['of',
#   'listens',
#   'it',
#   'does',
#   'of',
#   'is',
#   'i',
#   'of',
#   'walking',
#   'who',
#   'in',
#   'so',
#   'to',
#   'who',
#   'of',
#   'and',
#   'a',
#   'has',
#   'sorely',
#   'had',
#   'who',
#   'in',
#   'restored',
#   'would',
#   'who',
#   'of',
#   'high'],
#  ('man', 'of'): ['a', 'the', 'no', 'fifty', 'counsel', 'course', 'stone'],
#  ('of', 'a'): ['rugged',
#   'modest',
#   'friend',
#   'court',
#   'black',
#   'policeman',
#   'hill',
#   'man',
#   'sunday',
#   'few',
#   'fiend',
#   'relief',
#   'nocturnal',
#   'man',
#   'child',
#   'man',
#   'single',
#   'street',
#   'class',
#   'foul',
#   'country',
#   'slyish',
#   'well-founded',
#   'sudden',
#   'rich',
#   'man',
#   'million',
#   'connoisseur',
#   'green',
#   'celebrated',
#   'particular',
#   'mighty',
#   'swift',
#   'cheerful',
#   'melancholy',
#   'disappearance',
#   'friend',
#   'man',
#   'dwarf',
#   'footfall',
#   'break',
#   'sudden',
#   'man',
#   'self-destroyer',
#   'perfect',
#   'pious',
#   'white',
#   'blood-red',
#   'series',
#   'few',
#   'certain',
#   'reddish',
#   'pavilion',
#   'discovery',
#   'particular',
#   'great',
#   'heady',
#   'leap',
#   'fiend',
#   'life',
#   'passer-by',
#   'mid-london',
#   'dusky',
#   'more',
#   'more',
#   'change',
#   'closed',
#   'fancy',
#   'different',
#   'part',
#   'person',
#   'miracle'],
#  ('a', 'rugged'): ['countenance'],
#  ('rugged', 'countenance'): ['that'],
#  ('countenance', 'that'): ['was'],
#  ('that', 'was'): ['never',
#   'the',
#   'the',
#   'so',
#   'the',
#   'the',
#   'what',
#   'the',
#   'my',
#   'the',
#   'proved',
#   'definite',
#   'already',
#   'unbearable',
#   'no',
#   'projected',
#   'guilty',
#   'the'],
#  ('was', 'never'): ['lighted', 'more', 'dr', 'dr', 'a'],
#  ('never', 'lighted'): ['by'],
#  ('lighted', 'by'): ['a'],
#  ('by', 'a'): ['smile',
#   'sudden',
#   'long',
#   'bright',
#   'return',
#   'crime',
#   'second',
#   'constrained',
#   'marked',
#   'prodigy',
#   'cold',
#   'sense',
#   'great',
#   'combination'],
#  ('a', 'smile'): ['cold', 'but'],
#  ('smile', 'cold'): ['scanty'],
#  ('cold', 'scanty'): ['and'],
#  ('scanty', 'and'): ['embarrassed'],
#  ('and', 'embarrassed'): ['in'],
#  ('embarrassed', 'in'): ['discourse'],
#  ('in', 'discourse'): ['backward'],
#  ('discourse', 'backward'): ['in'],
#  ('backward', 'in'): ['sentiment'],
#  ('in', 'sentiment'): ['lean'],
#  ('sentiment', 'lean'): ['long'],
#  ('lean', 'long'): ['dusty'],
#  ('long', 'dusty'): ['dreary'],
#  ('dusty', 'dreary'): ['and'],
#  ('dreary', 'and'): ['yet'],
#  ('and', 'yet'): ['somehow',
#   'it’s',
#   'i',
#   'i',
#   'relieved',
#   'it',
#   'that',
#   'when',
#   'well',
#   'now',
#   'i',
#   'when',
#   'still',
#   'i',
#   'even'],
#  ('yet', 'somehow'): ['lovable'],
#  ('somehow', 'lovable'): ['at'],
#  ('lovable', 'at'): ['friendly'],
#  ('at', 'friendly'): ['meetings'],
#  ('friendly', 'meetings'): ['and'],
#  ('meetings', 'and'): ['when'],
#  ('and', 'when'): ['the',
#   'his',
#   'he',
#   'the',
#   'i',
#   'i',
#   'the',
#   'the',
#   'by',
#   'at',
#   'i'],
#  ('when', 'the'): ['wine',
#   'name',
#   'shops',
#   'light-hearted',
#   'stick',
#   'woman',
#   'trio',
#   'girl',
#   'attempt',
#   'ebullition',
#   'night',
#   'virtue'],
#  ('the', 'wine'): ['was', 'was'],
#  ('wine', 'was'): ['to', 'still'],
#  ('was', 'to'): ['his',
#   'get',
#   'be',
#   'his',
#   'rise',
#   'ask',
#   'place',
#   'have',
#   'die',
#   'die',
#   'fall'],
#  ('to', 'his'): ['taste',
#   'bachelor',
#   'toiling',
#   'brow',
#   'feet',
#   'house',
#   'detection',
#   'way',
#   'old',
#   'bed',
#   'dead',
#   'own',
#   'mind',
#   'account',
#   'eyes',
#   'office',
#   'origin',
#   'throat',
#   'lips',
#   'good',
#   'own',
#   'subordinate'],
#  ('his', 'taste'): ['something'],
#  ('taste', 'something'): ['eminently'],
#  ('something', 'eminently'): ['human'],
#  ('eminently', 'human'): ['beaconed'],
#  ('human', 'beaconed'): ['from'],
#  ('beaconed', 'from'): ['his'],
#  ('from', 'his'): ['eye',
#   'chair',
#   'pocket',
#   'pointing',
#   'blackguardly',
#   'balance',
#   'face',
#   'perch'],
#  ('his', 'eye'): ['something', 'there', 'lighted', 'and'],
#  ('eye', 'something'): ['indeed'],
#  ('something', 'indeed'): ['which'],
#  ('indeed', 'which'): ['never'],
#  ('which', 'never'): ['found'],
#  ('never', 'found'): ['its'],
#  ('found', 'its'): ['way'],
#  ('its', 'way'): ['into'],
#  ('way', 'into'): ['his', 'the', 'the', 'his'],
#  ('into', 'his'): ['talk', 'business', 'safe', 'hand', 'hands', 'presence'],
#  ('his', 'talk'): ['but'],
#  ('talk', 'but'): ['which'],
#  ('but', 'which'): ['spoke'],
#  ('which', 'spoke'): ['not'],
#  ('spoke', 'not'): ['only'],
#  ('not', 'only'): ['in',
#   'set',
#   'that',
#   'in',
#   'recognised',
#   'well',
#   'a',
#   'hellish'],
#  ('only', 'in'): ['these', 'the'],
#  ('in', 'these'): ['silent', 'two'],
#  ('these', 'silent'): ['symbols'],
#  ('silent', 'symbols'): ['of'],
#  ('symbols', 'of'): ['the'],
#  ('the', 'after-dinner'): ['face'],
#  ('after-dinner', 'face'): ['but'],
#  ('face', 'but'): ['more', 'of'],
#  ('but', 'more'): ['often'],
#  ('more', 'often'): ['and'],
#  ('often', 'and'): ['loudly'],
#  ('and', 'loudly'): ['in'],
#  ('loudly', 'in'): ['the'],
#  ('in', 'the'): ['acts',
#   'lives',
#   'object',
#   'affirmative',
#   'middle',
#   'morning',
#   'cheque',
#   'making',
#   'safe',
#   'direction',
#   'matter',
#   'gross',
#   'lawyer’s',
#   'mind',
#   'by-street',
#   'morning',
#   'air',
#   'course',
#   'face',
#   'key',
#   'dining-room',
#   'gloom',
#   'flickering',
#   'law',
#   'man’s',
#   'fire',
#   'month',
#   'small',
#   'middle',
#   'middle',
#   'neighbouring',
#   'morning',
#   'lawyer’s',
#   'doorways',
#   'whole',
#   'afternoon',
#   'grate',
#   'houses',
#   'square',
#   'cabinet',
#   'eddy',
#   'foundations',
#   'bottle',
#   'open',
#   'old',
#   'doctor’s',
#   'eye',
#   'meantime',
#   'mad',
#   'will',
#   'inmost',
#   'frequency',
#   'cabinet',
#   'face',
#   'garden',
#   'middle',
#   'eyes',
#   'same',
#   'year',
#   'cabinet',
#   'mask',
#   'theatre',
#   'quiet',
#   'quiet',
#   'middle',
#   'hand',
#   'by-street',
#   'cup',
#   'course',
#   'same',
#   'doctor’s',
#   'same',
#   'doctor’s',
#   'hall',
#   'hand',
#   'habit',
#   'fear',
#   'course',
#   'list',
#   'nature',
#   'very',
#   'man’s',
#   'world',
#   'way',
#   'next',
#   'year',
#   'world',
#   'majority',
#   'eye',
#   'field',
#   'agonised',
#   'moment',
#   'glass',
#   'bones',
#   'freshness',
#   'act',
#   'most',
#   'course',
#   'glass',
#   'ranks',
#   'square',
#   'person',
#   'public',
#   'hands',
#   'person',
#   'name',
#   'name',
#   'square',
#   'little',
#   'body',
#   'yellow',
#   'mere',
#   'morning',
#   'cabinet',
#   'light',
#   'beginning',
#   'pleasures',
#   'scales',
#   'fires',
#   'strength',
#   'disguise',
#   'top',
#   'same',
#   'future',
#   'last',
#   'sun',
#   'temper',
#   'dining-room',
#   'streets',
#   'private',
#   'corner',
#   'face',
#   'sea',
#   'morning',
#   'fire',
#   'confidence',
#   'ruin',
#   'glass',
#   'act'],
#  ('the', 'acts'): ['of', 'of'],
#  ('acts', 'of'): ['his', 'edward'],
#  ('of', 'his'): ['life',
#   'own',
#   'youth',
#   'friend',
#   'one',
#   'nightly',
#   'friend',
#   'spirits',
#   'relief',
#   'own',
#   'pleasant',
#   'address',
#   'mind',
#   'drive',
#   'friend’s',
#   'past',
#   'own',
#   'house',
#   'past',
#   'vile',
#   'strange',
#   'present',
#   'alarm',
#   'seclusion',
#   'exclusion',
#   'life',
#   'business',
#   'dead',
#   'predecease',
#   'private',
#   'surviving',
#   'visits',
#   'face',
#   'coming',
#   'voice',
#   'friends',
#   'face',
#   'face',
#   'entrance',
#   'collected',
#   'jaws',
#   'more',
#   'colleague',
#   'life',
#   'distress',
#   'ape-like'],
#  ('his', 'life'): ['he', 'were', 'had', 'his', 'and', 'was'],
#  ('life', 'he'): ['was'],
#  ('he', 'was'): ['austere',
#   'alone',
#   'undemonstrative',
#   'perfectly',
#   'the',
#   'like',
#   'quite',
#   'recalled',
#   'subjected',
#   'digging',
#   'aware',
#   'small',
#   'thus',
#   'now',
#   'ashamed',
#   'wild',
#   'young',
#   'humbled',
#   'liked',
#   'rude',
#   'trifling',
#   'trampling',
#   'out',
#   'conscious',
#   'not',
#   'often',
#   'at',
#   'surprised',
#   'by',
#   'not',
#   'simply',
#   'now',
#   'busy',
#   'much',
#   'not',
#   'shocked',
#   'visibly',
#   'dead',
#   'perhaps',
#   'out',
#   'surprised',
#   'to',
#   'made',
#   'at',
#   'dressed',
#   'looking',
#   'alive',
#   'to',
#   'small',
#   'wrestling',
#   'himself'],
#  ('was', 'austere'): ['with'],
#  ('austere', 'with'): ['himself'],
#  ('with', 'himself'): ['drank', 'why', 'the', 'upon'],
#  ('himself', 'drank'): ['gin'],
#  ('drank', 'gin'): ['when'],
#  ('gin', 'when'): ['he'],
#  ('when', 'he'): ['was',
#   'would',
#   'was',
#   'was',
#   'glanced',
#   'came',
#   'was',
#   'had',
#   'set',
#   'spoke'],
#  ('was', 'alone'): ['to'],
#  ('alone', 'to'): ['mortify', 'open', 'do'],
#  ('to', 'mortify'): ['a', 'curiosity'],
#  ('mortify', 'a'): ['taste'],
#  ('a', 'taste'): ['for'],
#  ('taste', 'for'): ['vintages'],
#  ('for', 'vintages'): ['and'],
#  ('vintages', 'and'): ['though'],
#  ('and', 'though'): ['he', 'of', 'he', 'i'],
#  ('though', 'he'): ['enjoyed', 'took', 'did', 'had'],
#  ('he', 'enjoyed'): ['the'],
#  ('enjoyed', 'the'): ['theatre', 'compensations'],
#  ('the', 'theatre'): ['had',
#   'once',
#   'from',
#   'continued',
#   'where',
#   'which',
#   'to',
#   'behind'],
#  ('theatre', 'had'): ['not'],
#  ('had', 'not'): ['crossed',
#   'once',
#   'conquered',
#   'wakened',
#   'been',
#   'done',
#   'been',
#   'of'],
#  ('not', 'crossed'): ['the'],
#  ('crossed', 'the'): ['doors', 'theatre', 'yard'],
#  ('the', 'doors'): ['of', 'of'],
#  ('doors', 'of'): ['one', 'the'],
#  ('of', 'one'): ['for', 'very', 'friend', 'of', 'of'],
#  ('one', 'for'): ['twenty'],
#  ('for', 'twenty'): ['years'],
#  ('twenty', 'years'): ['but', 'in', 'do'],
#  ('years', 'but'): ['he', 'i', 'for'],
#  ('but', 'he'): ['had',
#   'was',
#   'made',
#   'kept',
#   'answered',
#   'was',
#   'had',
#   'was',
#   'observed',
#   'recollected',
#   'loathed'],
#  ('he', 'had'): ['an',
#   'known',
#   'any',
#   'thought',
#   'come',
#   'thought',
#   'long',
#   'to',
#   'unlocked',
#   'a',
#   'borne',
#   'done',
#   'come',
#   'in',
#   'been',
#   'no',
#   'himself',
#   'been',
#   'gone',
#   'never',
#   'long',
#   'means',
#   'looked',
#   'to',
#   'never',
#   'left',
#   'always',
#   'in',
#   'his',
#   'been',
#   'long',
#   'grown',
#   'something',
#   'first',
#   'not',
#   'never',
#   'slipped',
#   'still',
#   'returned',
#   'no',
#   'received',
#   'done',
#   'lost',
#   'now'],
#  ('had', 'an'): ['approved', 'evil'],
#  ('an', 'approved'): ['tolerance'],
#  ('approved', 'tolerance'): ['for'],
#  ('tolerance', 'for'): ['others'],
#  ('for', 'others'): ['sometimes', 'and'],
#  ('others', 'sometimes'): ['wondering'],
#  ('sometimes', 'wondering'): ['almost'],
#  ('wondering', 'almost'): ['with'],
#  ('almost', 'with'): ['envy'],
#  ('with', 'envy'): ['at'],
#  ('envy', 'at'): ['the'],
#  ('the', 'high'): ['pressure', 'position', 'views'],
#  ('high', 'pressure'): ['of'],
#  ('pressure', 'of'): ['spirits'],
#  ('of', 'spirits'): ['involved', 'he'],
#  ('spirits', 'involved'): ['in'],
#  ('involved', 'in'): ['their'],
#  ('in', 'their'): ['misdeeds', 'sunday', 'eyes'],
#  ('their', 'misdeeds'): ['and'],
#  ('misdeeds', 'and'): ['in'],
#  ('and', 'in'): ['any',
#   'spite',
#   'the',
#   'the',
#   'something',
#   'case',
#   'spite',
#   'that',
#   'one',
#   'my',
#   'the',
#   'so',
#   'a',
#   'my',
#   'such',
#   'the',
#   'my',
#   'the'],
#  ('in', 'any'): ['extremity', 'point', 'man'],
#  ('any', 'extremity'): ['inclined'],
#  ('extremity', 'inclined'): ['to'],
#  ('inclined', 'to'): ['help', 'be'],
#  ('to', 'help'): ['rather', 'him', 'you'],
#  ('help', 'rather'): ['than'],
#  ('rather', 'than'): ['to', 'to'],
#  ('than', 'to'): ['reprove', 'be'],
#  ('to', 'reprove'): ['i'],
#  ('reprove', 'i'): ['incline'],
#  ('i', 'incline'): ['to'],
#  ('incline', 'to'): ['cain’s', 'the'],
#  ('to', 'cain’s'): ['heresy'],
#  ('cain’s', 'heresy'): ['he'],
#  ('heresy', 'he'): ['used'],
#  ('he', 'used'): ['to', 'a'],
#  ('used', 'to'): ['say', 'say', 'like', 'the', 'the'],
#  ('to', 'say'): ['quaintly',
#   'where',
#   'nothing',
#   'with',
#   'that',
#   'it',
#   'although',
#   'the'],
#  ('say', 'quaintly'): ['i'],
#  ('quaintly', 'i'): ['let'],
#  ('i', 'let'): ['my'],
#  ('let', 'my'): ['brother'],
#  ('my', 'brother'): ['go'],
#  ('brother', 'go'): ['to'],
#  ('go', 'to'): ['the', 'one', 'another'],
#  ('to', 'the'): ['devil',
#   'sawbones',
#   'other',
#   'bank',
#   'members',
#   'dining-room',
#   'eye',
#   'subject',
#   'great',
#   'quaint',
#   'lawyer',
#   'dust',
#   'wheel',
#   'very',
#   'other',
#   'earth',
#   'post',
#   'lawyer',
#   'police',
#   'man',
#   'bank',
#   'murderer’s',
#   'man',
#   'building',
#   'warmth',
#   'police',
#   'purpose',
#   'doctor’s',
#   'other',
#   'house',
#   'bottom',
#   'cabinet',
#   'unvarying',
#   'back',
#   'foot',
#   'lawyer',
#   'candle',
#   'same',
#   'attack',
#   'door',
#   'sound',
#   'cabinet',
#   'fireside',
#   'sitter’s',
#   'cheval-glass',
#   'business',
#   'floor',
#   'confession',
#   'bedside',
#   'sense',
#   'drawer',
#   'most',
#   'test',
#   'fatal',
#   'dryness',
#   'door',
#   'mirror',
#   'coming',
#   'other',
#   'liberty',
#   'civilities',
#   'topmost',
#   'house',
#   'better',
#   'world',
#   'old',
#   'gallows',
#   'importance',
#   'gallows',
#   'pitch',
#   'abhorrence',
#   'draught',
#   'moment'],
#  ('the', 'devil'): ['in'],
#  ('devil', 'in'): ['his'],
#  ('in', 'his'): ['own',
#   'demeanour',
#   'appearance',
#   'mind',
#   'own',
#   'dreams',
#   'blood',
#   'unobtrusive',
#   'hand',
#   'handwriting',
#   'veins',
#   'heart',
#   'life',
#   'voice',
#   'pocket',
#   'victim’s',
#   'own',
#   'pocket',
#   'hands',
#   'stead',
#   'study',
#   'misfitting',
#   'flesh'],
#  ('his', 'own'): ['way',
#   'blood',
#   'back',
#   'past',
#   'black',
#   'tastes',
#   'hearth',
#   'state',
#   'jangled',
#   'hand',
#   'shape',
#   'thoughts',
#   'face'],
#  ('own', 'way'): ['in'],
#  ('way', 'in'): ['this', 'silence'],
#  ('in', 'this'): ['character', 'world', 'man’s', 'glass', 'room', 'case'],
#  ('this', 'character'): ['it'],
#  ('character', 'it'): ['was'],
#  ('it', 'was'): ['frequently',
#   'a',
#   'reported',
#   'two',
#   'this',
#   'hellish',
#   'like',
#   'a',
#   'only',
#   'a',
#   'a',
#   'his',
#   'made',
#   'his',
#   'his',
#   'already',
#   'worse',
#   'madness',
#   'a',
#   'but',
#   'that',
#   'a',
#   'with',
#   'now',
#   'two',
#   'of',
#   'he',
#   'by',
#   'nearly',
#   'impossible',
#   'late',
#   'the',
#   'a',
#   'hyde',
#   'at',
#   'not',
#   'not',
#   'unlikely',
#   'with',
#   'emphatically',
#   'disappearance',
#   'set',
#   'impossible',
#   'partly',
#   'not',
#   'a',
#   'brightly',
#   'sometimes',
#   'not',
#   'this',
#   'but',
#   'my',
#   'but',
#   'never',
#   'you',
#   'much',
#   'mr',
#   'now',
#   'different',
#   'not',
#   'locked',
#   'so',
#   'a',
#   'plain',
#   'thus',
#   'on',
#   'only',
#   'the',
#   'was',
#   'because',
#   'neither',
#   'on',
#   'hyde',
#   'possible',
#   'in',
#   'large',
#   'the',
#   'well',
#   'by',
#   'not',
#   'succeeded',
#   'not',
#   'in',
#   'as',
#   'a',
#   'at',
#   'no',
#   'the',
#   'partly',
#   'always',
#   'a',
#   'without',
#   'in',
#   'that'],
#  ('was', 'frequently'): ['his'],
#  ('frequently', 'his'): ['fortune'],
#  ('his', 'fortune'): ['to', 'and'],
#  ('fortune', 'to'): ['be'],
#  ('to', 'be'): ['the',
#   'founded',
#   'seen',
#   'clothed',
#   'found',
#   'sure',
#   'trusted',
#   'lying',
#   'had',
#   'set',
#   'destroyed',
#   'opened',
#   'denied',
#   'admitted',
#   'irritated',
#   'heard',
#   'deceived',
#   'smuggled',
#   'still',
#   'explained',
#   'forced',
#   'preferred',
#   'alone',
#   'used',
#   'received',
#   'set',
#   'either',
#   'the',
#   'more',
#   'most',
#   'the',
#   'attempted',
#   'seen',
#   'humourous',
#   'silent',
#   'but',
#   'explained',
#   'remedied',
#   'spelling',
#   'tortured',
#   'tempted',
#   'forfeit',
#   'aware',
#   'reached',
#   're-administered',
#   'born'],
#  ('be', 'the'): ['last', 'two', 'old', 'last', 'lethal'],
#  ('last', 'reputable'): ['acquaintance'],
#  ('reputable', 'acquaintance'): ['and'],
#  ('acquaintance', 'and'): ['the'],
#  ('and', 'the'): ['last',
#   'lawyer',
#   'other',
#   'child’s',
#   'person',
#   'family',
#   'young',
#   'curtained',
#   'rumour',
#   'look',
#   'pair',
#   'next',
#   'agents',
#   'uneasy',
#   'lawyer',
#   'lawyer',
#   'danger',
#   'lane',
#   'girl',
#   'body',
#   'next',
#   'first',
#   'law’s',
#   'next',
#   'inspector',
#   'carpets',
#   'few',
#   'light',
#   'glow',
#   'clerk',
#   'face',
#   'sixth',
#   'knowledge',
#   'next',
#   'whole',
#   'lawyer',
#   'name',
#   'packet',
#   'thin',
#   'cook',
#   'beetles',
#   'very',
#   'avoidance',
#   'creature',
#   'boy',
#   'better',
#   'red',
#   'frame',
#   'fittings',
#   'wreck',
#   'stillness',
#   'strong',
#   'fractures',
#   'tea',
#   'locksmith',
#   'record',
#   'collar',
#   'horror',
#   'next',
#   'compound',
#   'features',
#   'next',
#   'transcendental',
#   'intellectual',
#   'just',
#   'thought',
#   'face',
#   'thing',
#   'other',
#   'successive',
#   'child’s',
#   'design',
#   'character',
#   'hands',
#   'regent’s',
#   'most',
#   'smile',
#   'drug',
#   'time',
#   'first'],
#  ('last', 'good'): ['influence'],
#  ('good', 'influence'): ['in'],
#  ('influence', 'in'): ['the'],
#  ('the', 'lives'): ['of'],
#  ('lives', 'of'): ['downgoing'],
#  ('of', 'downgoing'): ['men'],
#  ('downgoing', 'men'): ['and'],
#  ('men', 'and'): ['to', 'all', 'women'],
#  ('and', 'to'): ['such',
#   'disperse',
#   'grow',
#   'sit',
#   'draw',
#   'place',
#   'turn',
#   'reinforce',
#   'throw',
#   'go',
#   'assume',
#   'parry',
#   'become',
#   'make'],
#  ('to', 'such'): ['as', 'a'],
#  ('such', 'as'): ['these', 'has', 'i'],
#  ('as', 'these'): ['so'],
#  ('these', 'so'): ['long'],
#  ('so', 'long'): ['as', 'baffled', 'been', 'indulged'],
#  ('long', 'as'): ['they', 'i'],
#  ('as', 'they'): ['came', 'say', 'turned', 'are', 'opened', 'stand', 'must'],
#  ('they', 'came'): ['about', 'abreast', 'in', 'into'],
#  ('came', 'about'): ['his', 'that', 'that', 'that'],
#  ('about', 'his'): ['chambers', 'eyes', 'voice'],
#  ('his', 'chambers'): ['he'],
#  ('chambers', 'he'): ['never'],
#  ('he', 'never'): ['marked', 'told', 'dines', 'would'],
#  ('never', 'marked'): ['a'],
#  ('marked', 'a'): ['shade'],
#  ('a', 'shade'): ['of'],
#  ('shade', 'of'): ['change'],
#  ('of', 'change'): ['in', 'take'],
#  ('change', 'in'): ['his', 'the'],
#  ('his', 'demeanour'): ['no'],
#  ('demeanour', 'no'): ['doubt'],
#  ('no', 'doubt'): ['the', 'the', 'i', 'you'],
#  ('doubt', 'the'): ['feat', 'bond'],
#  ('the', 'feat'): ['was'],
#  ('feat', 'was'): ['easy'],
#  ('was', 'easy'): ['to'],
#  ('easy', 'to'): ['mr', 'describe'],
#  ('to', 'mr'): ['utterson', 'richard', 'utterson', 'utterson’s'],
#  ('utterson', 'for'): ['he'],
#  ('for', 'he'): ['was'],
#  ('was', 'undemonstrative'): ['at'],
#  ('undemonstrative', 'at'): ['the'],
#  ('the', 'best'): ['and', 'but', 'thing'],
#  ('best', 'and'): ['even'],
#  ('and', 'even'): ['his', 'at', 'for', 'outside', 'as', 'as', 'granting'],
#  ('even', 'his'): ['friendship'],
#  ('his', 'friendship'): ['seemed'],
#  ('friendship', 'seemed'): ['to'],
#  ('seemed', 'to'): ['be',
#   'read',
#   'breathe',
#   'listen',
#   'have',
#   'open',
#   'testify',
#   'have',
#   'me',
#   'me',
#   'swell',
#   'melt',
#   'me',
#   'be',
#   'me',
#   'point',
#   'have',
#   'utter'],
#  ('be', 'founded'): ['in'],
#  ('founded', 'in'): ['a'],
#  ('in', 'a'): ['similar',
#   'busy',
#   'forest',
#   'body',
#   'great',
#   'scroll',
#   'rich',
#   'house',
#   'great',
#   'nightmare',
#   'changed',
#   'loud',
#   'moment',
#   'very',
#   'position',
#   'hundred',
#   'strange',
#   'position',
#   'body',
#   'sheet',
#   'total',
#   'fashion',
#   'voice',
#   'more',
#   'moment',
#   'cheque',
#   'dream',
#   'dream'],
#  ('a', 'similar'): ['catholicity'],
#  ('similar', 'catholicity'): ['of'],
#  ('catholicity', 'of'): ['good-nature'],
#  ('of', 'good-nature'): ['it'],
#  ('good-nature', 'it'): ['is'],
#  ('it', 'is'): ['the',
#   'connected',
#   'returned',
#   'because',
#   'disgrace',
#   'more',
#   'nothing',
#   'as',
#   'on',
#   'one',
#   'not',
#   'all',
#   'between',
#   'an',
#   'quite',
#   'an',
#   'as',
#   'a',
#   'one',
#   'quite',
#   'i',
#   'that',
#   'for',
#   'sad',
#   'plain',
#   'the',
#   'well',
#   'now',
#   'broken',
#   'now',
#   'possible',
#   'sir',
#   'well',
#   'useless'],
#  ('is', 'the'): ['mark',
#   'very',
#   'doctor',
#   'belief',
#   'same',
#   'same',
#   'first',
#   'last'],
#  ('the', 'mark'): ['of'],
#  ('mark', 'of'): ['a', 'capacity', 'having'],
#  ('a', 'modest'): ['man'],
#  ('modest', 'man'): ['to'],
#  ('man', 'to'): ['accept', 'be', 'satisfy'],
#  ('to', 'accept'): ['his'],
#  ('accept', 'his'): ['friendly'],
#  ('his', 'friendly'): ['circle'],
#  ('friendly', 'circle'): ['ready-made'],
#  ('circle', 'ready-made'): ['from'],
#  ('ready-made', 'from'): ['the'],
#  ('from', 'the'): ['hands',
#   'most',
#   'door',
#   'doctor’s',
#   'vast',
#   'entry',
#   'by-street',
#   'corner',
#   'river',
#   'heirs',
#   'fire',
#   'time',
#   'hotness',
#   'house',
#   'sinister',
#   'garden',
#   'chemist',
#   'heavy',
#   'cabinet',
#   'times',
#   'top',
#   'bottom',
#   'first',
#   'ground',
#   'high',
#   'nature',
#   'aspirations',
#   'laboratory',
#   'mere',
#   'future',
#   'scene',
#   'days',
#   'action'],
#  ('the', 'hands'): ['of', 'of', 'of', 'of', 'of', 'of'],
#  ('hands', 'of'): ['opportunity', 'his', 'g', 'this', 'edward', 'all'],
#  ('of', 'opportunity'): ['and'],
#  ('opportunity', 'and'): ['that'],
#  ('and', 'that'): ['was',
#   'a',
#   'human',
#   'was',
#   'his',
#   'is',
#   'when',
#   'by',
#   'i',
#   'if',
#   'when',
#   'i',
#   'the',
#   'the',
#   'he',
#   'it'],
#  ('was', 'the'): ['lawyer’s',
#   'usual',
#   'man',
#   'reply',
#   'immodest',
#   'way',
#   'reply',
#   'amount',
#   'habit',
#   'reply',
#   'home',
#   'haunting',
#   'first',
#   'reply',
#   'messenger',
#   'funeral',
#   'reply',
#   'answer',
#   'undaunted',
#   'answer',
#   'curse',
#   'first',
#   'first',
#   'hand',
#   'common',
#   'problem',
#   'horror',
#   'shocking'],
#  ('the', 'lawyer’s'): ['way', 'eyesore', 'mind', 'eyes', 'notice'],
#  ('lawyer’s', 'way'): ['his'],
#  ('way', 'his'): ['friends'],
#  ('his', 'friends'): ['were', 'became', 'hence'],
#  ('friends', 'were'): ['those', 'younger'],
#  ('were', 'those'): ['of'],
#  ('those', 'of'): ['his'],
#  ('own', 'blood'): ['or'],
#  ('blood', 'or'): ['those'],
#  ('or', 'those'): ['whom'],
#  ('those', 'whom'): ['he'],
#  ('whom', 'he'): ['had', 'had', 'kept'],
#  ('had', 'known'): ['the'],
#  ('known', 'the'): ['longest'],
#  ('the', 'longest'): ['his'],
#  ('longest', 'his'): ['affections'],
#  ('his', 'affections'): ['like'],
#  ('affections', 'like'): ['ivy'],
#  ('like', 'ivy'): ['were'],
#  ('ivy', 'were'): ['the'],
#  ('were', 'the'): ['growth',
#   'girl’s',
#   'idea',
#   'expression',
#   'terms',
#   'leading'],
#  ('the', 'growth'): ['of'],
#  ('growth', 'of'): ['time', 'hair'],
#  ('of', 'time'): ['they'],
#  ('time', 'they'): ['implied'],
#  ('they', 'implied'): ['no'],
#  ('implied', 'no'): ['aptness'],
#  ('no', 'aptness'): ['in'],
#  ('aptness', 'in'): ['the'],
#  ('the', 'object'): ['hence'],
#  ('object', 'hence'): ['no'],
#  ('hence', 'no'): ['doubt'],
#  ('the', 'bond'): ['that'],
#  ('bond', 'that'): ['united'],
#  ('that', 'united'): ['him'],
#  ('united', 'him'): ['to'],
#  ('him', 'to'): ['mr', 'the', 'the', 'stand', 'be', 'death'],
#  ('mr', 'richard'): ['enfield'],
#  ('richard', 'enfield'): ['his'],
#  ('enfield', 'his'): ['distant'],
#  ('his', 'distant'): ['kinsman'],
#  ('distant', 'kinsman'): ['the'],
#  ('kinsman', 'the'): ['well-known', 'doctor'],
#  ('the', 'well-known'): ['man'],
#  ('well-known', 'man'): ['about'],
#  ('man', 'about'): ['town'],
#  ('about', 'town'): ['it'],
#  ('town', 'it'): ['was'],
#  ('a', 'nut'): ['to'],
#  ('nut', 'to'): ['crack'],
#  ('to', 'crack'): ['for'],
#  ('crack', 'for'): ['many'],
#  ('for', 'many'): ['what'],
#  ('many', 'what'): ['these'],
#  ('what', 'these'): ['two'],
#  ('these', 'two'): ['could', 'were', 'phases', 'i', 'base'],
#  ('two', 'could'): ['see'],
#  ('could', 'see'): ['in', 'that', 'by', 'in'],
#  ('see', 'in'): ['each', 'spite'],
#  ('in', 'each'): ['other'],
#  ('each', 'other'): ['or', 'and', 'pretty', 'with'],
#  ('other', 'or'): ['what'],
#  ('or', 'what'): ['subject'],
#  ('what', 'subject'): ['they'],
#  ('subject', 'they'): ['could'],
#  ('they', 'could'): ['find'],
#  ('could', 'find'): ['in', 'a'],
#  ('find', 'in'): ['common'],
#  ('in', 'common'): ['it', 'but'],
#  ('common', 'it'): ['was'],
#  ('was', 'reported'): ['by'],
#  ('reported', 'by'): ['those'],
#  ('by', 'those'): ['who'],
#  ('those', 'who'): ['encountered'],
#  ('who', 'encountered'): ['them'],
#  ('encountered', 'them'): ['in'],
#  ('them', 'in'): ['their', 'my', 'a'],
#  ('their', 'sunday'): ['walks'],
#  ('sunday', 'walks'): ['that'],
#  ('walks', 'that'): ['they'],
#  ('that', 'they'): ['said', 'might', 'should'],
#  ('they', 'said'): ['nothing'],
#  ('said', 'nothing'): ['looked'],
#  ('nothing', 'looked'): ['singularly'],
#  ('looked', 'singularly'): ['dull'],
#  ('singularly', 'dull'): ['and'],
#  ('dull', 'and'): ['would'],
#  ('and', 'would'): ['hail', 'make'],
#  ('would', 'hail'): ['with'],
#  ('hail', 'with'): ['obvious'],
#  ('with', 'obvious'): ['relief'],
#  ('obvious', 'relief'): ['the'],
#  ('relief', 'the'): ['appearance'],
#  ('the', 'appearance'): ['of', 'of'],
#  ('appearance', 'of'): ['a', 'edward'],
#  ('a', 'friend'): ['for', 'might'],
#  ('friend', 'for'): ['all'],
#  ('for', 'all'): ['that', 'that', 'that', 'the', 'they', 'were', 'his'],
#  ('all', 'that'): ['the', 'continued', 'an', 'was', 'he'],
#  ('that', 'the'): ['two',
#   'shop',
#   'whole',
#   'lawyer',
#   'ghost',
#   'topic',
#   'lawyer',
#   'writer’s',
#   'doctor',
#   'wine',
#   'doctor’s',
#   'lock',
#   'end',
#   'post-office',
#   'entries',
#   'direction',
#   'doom',
#   'servants',
#   'murder',
#   'guilt',
#   'victim',
#   'days',
#   'slime',
#   'amorphous'],
#  ('the', 'two'): ['men',
#   'ran',
#   'oldest',
#   'sheets',
#   'hands',
#   'gentlemen',
#   'men',
#   'narratives',
#   'natures'],
#  ('two', 'men'): ['put', 'looked'],
#  ('men', 'put'): ['the'],
#  ('put', 'the'): ['greatest', 'glass'],
#  ('the', 'greatest'): ['store'],
#  ('greatest', 'store'): ['by'],
#  ('store', 'by'): ['these'],
#  ('by', 'these'): ['excursions', 'that'],
#  ('these', 'excursions'): ['counted', 'i'],
#  ('excursions', 'counted'): ['them'],
#  ('counted', 'them'): ['the'],
#  ('them', 'the'): ['chief'],
#  ('the', 'chief'): ['jewel', 'of', 'of'],
#  ('chief', 'jewel'): ['of'],
#  ('jewel', 'of'): ['each'],
#  ('of', 'each'): ['week', 'other'],
#  ('each', 'week'): ['and'],
#  ('week', 'and'): ['not'],
#  ('and', 'not'): ['only'],
#  ('only', 'set'): ['aside'],
#  ('set', 'aside'): ['occasions', 'without'],
#  ('aside', 'occasions'): ['of'],
#  ('occasions', 'of'): ['pleasure'],
#  ('of', 'pleasure'): ['but'],
#  ('pleasure', 'but'): ['even'],
#  ('but', 'even'): ['resisted', 'as', 'if'],
#  ('even', 'resisted'): ['the'],
#  ('resisted', 'the'): ['calls', 'action'],
#  ('the', 'calls'): ['of'],
#  ('calls', 'of'): ['business'],
#  ('of', 'business'): ['that', 'of'],
#  ('business', 'that'): ['they'],
#  ('they', 'might'): ['enjoy'],
#  ('might', 'enjoy'): ['them'],
#  ('enjoy', 'them'): ['uninterrupted'],
#  ('them', 'uninterrupted'): ['it'],
#  ('uninterrupted', 'it'): ['chanced'],
#  ('it', 'chanced'): ['on', 'on', 'that'],
#  ('chanced', 'on'): ['one', 'sunday'],
#  ('on', 'one'): ['of', 'point', 'side', 'side'],
#  ('one', 'of'): ['these',
#   'the',
#   'your',
#   'a',
#   'his',
#   'those',
#   'the',
#   'those',
#   'my',
#   'those',
#   'them',
#   'the',
#   'the',
#   'the',
#   'my',
#   'my',
#   'the'],
#  ('of', 'these'): ['rambles',
#   'together',
#   'sights',
#   'fallen',
#   'mysteries',
#   'reports',
#   'papers',
#   'articles',
#   'elements',
#   'sensations',
#   'transformations',
#   'excesses'],
#  ('these', 'rambles'): ['that'],
#  ('rambles', 'that'): ['their'],
#  ('that', 'their'): ['way', 'way', 'last', 'unsleeping'],
#  ('their', 'way'): ['led', 'lay'],
#  ('way', 'led'): ['them'],
#  ('led', 'them'): ['down'],
#  ('them', 'down'): ['a'],
#  ('down', 'a'): ['by-street', 'cross', 'storm'],
#  ('a', 'by-street'): ['in'],
#  ('by-street', 'in'): ['a'],
#  ('a', 'busy'): ['quarter'],
#  ('busy', 'quarter'): ['of'],
#  ('quarter', 'of'): ['london', 'soho', 'a'],
#  ('of', 'london'): ['the', 'to', 'from', 'insensibly', 'so'],
#  ('london', 'the'): ['street'],
#  ('the', 'street'): ['was', 'shone', 'it', 'the', 'pausing'],
#  ('street', 'was'): ['small'],
#  ('was', 'small'): ['and', 'and', 'as'],
#  ('small', 'and'): ['what', 'very', 'particularly'],
#  ('and', 'what'): ['is', 'was', 'makes', 'does', 'of', 'is'],
#  ('what', 'is'): ['called', 'far', 'to'],
#  ('is', 'called'): ['quiet'],
#  ('called', 'quiet'): ['but'],
#  ('quiet', 'but'): ['it', 'i'],
#  ('but', 'it'): ['drove',
#   'was',
#   'was',
#   'reposed',
#   'is',
#   'bore',
#   'is',
#   'is',
#   'was',
#   'is',
#   'was',
#   'did'],
#  ('it', 'drove'): ['a'],
#  ('drove', 'a'): ['thriving'],
#  ('a', 'thriving'): ['trade'],
#  ('thriving', 'trade'): ['on'],
#  ('trade', 'on'): ['the'],
#  ('on', 'the'): ['weekdays',
#   'left',
#   'street',
#   'lower',
#   'upper',
#   'panels',
#   'mouldings',
#   'other',
#   'ground',
#   'top',
#   'head',
#   'court',
#   'first',
#   'envelope',
#   'bells',
#   'intellectual',
#   'shoulder',
#   'tall',
#   'polished',
#   'roof',
#   'threshold',
#   'opposite',
#   'hearth',
#   'chimney',
#   'intimacy',
#   'wing',
#   'morning',
#   '8th',
#   '12th',
#   '14th',
#   '15th',
#   'trustee',
#   'chain',
#   'red',
#   'floor',
#   'stair',
#   'carpet',
#   'hearth',
#   'business',
#   'body',
#   'by-street',
#   'flags',
#   'flags',
#   'roof',
#   'desk',
#   'ninth',
#   'left',
#   'receipt',
#   'door',
#   'floor',
#   'same',
#   'moral',
#   'thought',
#   'face',
#   'other',
#   'bedclothes',
#   'wall',
#   'issues',
#   'famous',
#   'pages'],
#  ('the', 'weekdays'): ['the'],
#  ('weekdays', 'the'): ['inhabitants'],
#  ('the', 'inhabitants'): ['were'],
#  ('inhabitants', 'were'): ['all'],
#  ('were', 'all'): ['doing'],
#  ('all', 'doing'): ['well'],
#  ('doing', 'well'): ['it'],
#  ('well', 'it'): ['seemed', 'was'],
#  ('it', 'seemed'): ['and', 'to', 'as', 'to', 'natural', 'more', 'to', 'only'],
#  ('seemed', 'and'): ['all'],
#  ('and', 'all'): ['emulously',
#   'the',
#   'as',
#   'the',
#   'judges',
#   'disreputable',
#   'by',
#   'the'],
#  ('all', 'emulously'): ['hoping'],
#  ('emulously', 'hoping'): ['to'],
#  ('hoping', 'to'): ['do'],
#  ('to', 'do'): ['better',
#   'with',
#   'but',
#   'about',
#   'the',
#   'it',
#   'at',
#   'as',
#   'much',
#   'his'],
#  ('do', 'better'): ['still'],
#  ('better', 'still'): ['and'],
#  ('still', 'and'): ['laying'],
#  ('and', 'laying'): ['out'],
#  ('laying', 'out'): ['the'],
#  ('out', 'the'): ['surplus',
#   'sweat',
#   'hour',
#   'handbills',
#   'lawyer',
#   'drawer',
#   'warnings',
#   'letters'],
#  ('the', 'surplus'): ['of'],
#  ('surplus', 'of'): ['their'],
#  ('of', 'their'): ['gains', 'life', 'review', 'neglect', 'being'],
#  ('their', 'gains'): ['in'],
#  ('gains', 'in'): ['coquetry'],
#  ('in', 'coquetry'): ['so'],
#  ('coquetry', 'so'): ['that'],
#  ('so', 'that'): ['the', 'as', 'it', 'to', 'if'],
#  ('the', 'shop'): ['fronts'],
#  ('shop', 'fronts'): ['stood'],
#  ('fronts', 'stood'): ['along'],
#  ('stood', 'along'): ['that'],
#  ('along', 'that'): ['thoroughfare'],
#  ('that', 'thoroughfare'): ['with'],
#  ('thoroughfare', 'with'): ['an'],
#  ('with', 'an'): ['air',
#   'air',
#   'ill-contained',
#   'inward',
#   'air',
#   'infinite',
#   'occasional',
#   'involuntary',
#   'air',
#   'almost',
#   'overpowering'],
#  ('an', 'air'): ['of', 'of', 'of', 'of'],
#  ('air', 'of'): ['invitation',
#   'defiance',
#   'wealth',
#   'one',
#   'great',
#   'scrutiny'],
#  ('of', 'invitation'): ['like'],
#  ('invitation', 'like'): ['rows'],
#  ('like', 'rows'): ['of'],
#  ('rows', 'of'): ['smiling'],
#  ('of', 'smiling'): ['saleswomen'],
#  ('smiling', 'saleswomen'): ['even'],
#  ('saleswomen', 'even'): ['on'],
#  ('even', 'on'): ['sunday'],
#  ('on', 'sunday'): ['when', 'when'],
#  ('sunday', 'when'): ['it', 'this', 'mr'],
#  ('when', 'it'): ['veiled', 'began', 'shall'],
#  ('it', 'veiled'): ['its'],
#  ('veiled', 'its'): ['more'],
#  ('its', 'more'): ['florid'],
#  ('more', 'florid'): ['charms'],
#  ('florid', 'charms'): ['and'],
#  ('charms', 'and'): ['lay'],
#  ('and', 'lay'): ['comparatively'],
#  ('lay', 'comparatively'): ['empty'],
#  ('comparatively', 'empty'): ['of'],
#  ('empty', 'of'): ['passage'],
#  ('of', 'passage'): ['the'],
#  ('passage', 'the'): ['street'],
#  ('street', 'shone'): ['out'],
#  ('shone', 'out'): ['in'],
#  ('out', 'in'): ['contrast', 'a'],
#  ('in', 'contrast'): ['to'],
#  ('contrast', 'to'): ['its'],
#  ('to', 'its'): ['dingy', 'author', 'roots'],
#  ('its', 'dingy'): ['neighbourhood'],
#  ('dingy', 'neighbourhood'): ['like'],
#  ('neighbourhood', 'like'): ['a'],
#  ('like', 'a'): ['fire',
#   'man',
#   'man',
#   'thief',
#   'madman',
#   'district',
#   'flock',
#   'rat',
#   'monkey',
#   'woman',
#   'story',
#   'man',
#   'millrace',
#   'thick',
#   'schoolboy',
#   'man',
#   'return',
#   'tempest'],
#  ('a', 'fire'): ['in'],
#  ('fire', 'in'): ['a', 'the', 'the'],
#  ('a', 'forest'): ['and'],
#  ('forest', 'and'): ['with'],
#  ('and', 'with'): ['its', 'the', 'the', 'this', 'that', 'this', 'as', 'even'],
#  ('with', 'its'): ['freshly', 'muddy', 'inscrutable', 'lumber'],
#  ('its', 'freshly'): ['painted'],
#  ('freshly', 'painted'): ['shutters'],
#  ('painted', 'shutters'): ['well-polished'],
#  ('shutters', 'well-polished'): ['brasses'],
#  ('well-polished', 'brasses'): ['and'],
#  ('brasses', 'and'): ['general'],
#  ('and', 'general'): ['cleanliness'],
#  ('general', 'cleanliness'): ['and'],
#  ('cleanliness', 'and'): ['gaiety'],
#  ('and', 'gaiety'): ['of'],
#  ('gaiety', 'of'): ['note', 'disposition'],
#  ('of', 'note'): ['instantly'],
#  ('note', 'instantly'): ['caught'],
#  ('instantly', 'caught'): ['and'],
#  ('caught', 'and'): ['pleased'],
#  ('and', 'pleased'): ['the'],
#  ('pleased', 'the'): ['eye'],
#  ('the', 'eye'): ['of', 'but', 'and', 'of'],
#  ('eye', 'of'): ['the', 'day'],
#  ('the', 'passenger'): ['two'],
#  ('passenger', 'two'): ['doors'],
#  ('two', 'doors'): ['from'],
#  ('doors', 'from'): ['one'],
#  ('from', 'one'): ['corner', 'end', 'to'],
#  ('one', 'corner'): ['on'],
#  ('corner', 'on'): ['the'],
#  ('the', 'left'): ['hand', 'hand'],
#  ('left', 'hand'): ['going', 'to', 'breaking'],
#  ('hand', 'going'): ['east'],
#  ('going', 'east'): ['the'],
#  ('east', 'the'): ['line'],
#  ('the', 'line'): ['was'],
#  ('line', 'was'): ['broken'],
#  ('was', 'broken'): ['by'],
#  ('broken', 'by'): ['the', 'the'],
#  ('by', 'the'): ['entry',
#   'fire',
#   'fire',
#   'old',
#   'laboratory',
#   'thought',
#   'many',
#   'many',
#   'look',
#   'high',
#   'full',
#   'murderer',
#   'kitchen',
#   'bye',
#   'laboratory',
#   'disappearance',
#   'light',
#   'hand',
#   'hand',
#   'air',
#   'way',
#   'laboratory',
#   'back',
#   'sounds',
#   'crushed',
#   'theatre',
#   'cabinet',
#   'dust',
#   'fall',
#   'evening',
#   'neglect',
#   'same',
#   'name',
#   'hands',
#   'least',
#   'police',
#   'strange',
#   'dangers',
#   'terrors',
#   'house',
#   'sleeplessness'],
#  ('the', 'entry'): ['of', 'the', 'of', 'could'],
#  ('entry', 'of'): ['a', 'the'],
#  ('a', 'court'): ['and'],
#  ('court', 'and'): ['just', 'take', 'through'],
#  ('and', 'just'): ['at', 'to'],
#  ('just', 'at'): ['that'],
#  ('at', 'that'): ['point',
#   'dead',
#   'distance',
#   'mr',
#   'was',
#   'date',
#   'time',
#   'time'],
#  ('that', 'point'): ['a', 'others'],
#  ('point', 'a'): ['certain'],
#  ('a', 'certain'): ['sinister',
#   'incoherency',
#   'mr',
#   'apprehension',
#   'swing',
#   'icy',
#   'impatient',
#   'callousness',
#   'acquiescence'],
#  ('certain', 'sinister'): ['block'],
#  ('sinister', 'block'): ['of'],
#  ('block', 'of'): ['building'],
#  ('of', 'building'): ['thrust', 'tossed'],
#  ('building', 'thrust'): ['forward'],
#  ('thrust', 'forward'): ['its'],
#  ('forward', 'its'): ['gable'],
#  ('its', 'gable'): ['on'],
#  ('gable', 'on'): ['the'],
#  ('street', 'it'): ['was'],
#  ('was', 'two'): ['storeys', 'o’clock'],
#  ('two', 'storeys'): ['high'],
#  ('storeys', 'high'): ['showed'],
#  ('high', 'showed'): ['no'],
#  ('showed', 'no'): ['window'],
#  ('no', 'window'): ['nothing'],
#  ('window', 'nothing'): ['but'],
#  ('nothing', 'but'): ['a', 'papers', 'the'],
#  ('but', 'a'): ['door',
#   'name',
#   'thing',
#   'hide-bound',
#   'man',
#   'glance',
#   'series',
#   'moment',
#   'second',
#   'drop',
#   'certain'],
#  ('a', 'door'): ['on', 'covered'],
#  ('door', 'on'): ['the', 'the'],
#  ('the', 'lower'): ['storey', 'side'],
#  ('lower', 'storey'): ['and'],
#  ('storey', 'and'): ['a', 'was'],
#  ('and', 'a'): ['blind',
#   'cheque',
#   'boisterous',
#   'trifle',
#   'haggard',
#   'business',
#   'danger',
#   'little',
#   'voice',
#   'closed',
#   'spacious',
#   'paper',
#   'carpenter',
#   'second',
#   'horror',
#   'body'],
#  ('a', 'blind'): ['forehead'],
#  ('blind', 'forehead'): ['of'],
#  ('forehead', 'of'): ['discoloured'],
#  ('of', 'discoloured'): ['wall'],
#  ('discoloured', 'wall'): ['on'],
#  ('wall', 'on'): ['the'],
#  ('the', 'upper'): ['and'],
#  ('upper', 'and'): ['bore'],
#  ('and', 'bore'): ['in', 'in', 'the'],
#  ('bore', 'in'): ['every', 'the'],
#  ('in', 'every'): ['feature', 'step', 'measurement', 'corner'],
#  ('every', 'feature'): ['the'],
#  ('feature', 'the'): ['marks'],
#  ('the', 'marks'): ['of'],
#  ('marks', 'of'): ['prolonged', 'exclamation'],
#  ('of', 'prolonged'): ['and'],
#  ('prolonged', 'and'): ['sordid'],
#  ('and', 'sordid'): ['negligence'],
#  ('sordid', 'negligence'): ['the'],
#  ('negligence', 'the'): ['door'],
#  ('door', 'which'): ['was'],
#  ('which', 'was'): ['equipped',
#   'only',
#   'just',
#   'indifferently',
#   'highly',
#   'at',
#   'indeed'],
#  ('was', 'equipped'): ['with'],
#  ('equipped', 'with'): ['neither'],
#  ('with', 'neither'): ['bell'],
#  ('neither', 'bell'): ['nor'],
#  ('bell', 'nor'): ['knocker'],
#  ('nor', 'knocker'): ['was'],
#  ('knocker', 'was'): ['blistered'],
#  ('was', 'blistered'): ['and'],
#  ('blistered', 'and'): ['distained'],
#  ('and', 'distained'): ['tramps'],
#  ('distained', 'tramps'): ['slouched'],
#  ('tramps', 'slouched'): ['into'],
#  ('slouched', 'into'): ['the'],
#  ('into', 'the'): ['recess',
#   'hands',
#   'said',
#   'entry',
#   'house',
#   'cell',
#   'doctor’s',
#   'court',
#   'face',
#   'laboratory',
#   'great',
#   'theatre',
#   'cabinet',
#   'cabinet',
#   'cabinet',
#   'yard',
#   'shelter',
#   'house',
#   'darkness',
#   'bright',
#   'morning',
#   'sea',
#   'details',
#   'elements',
#   'midst',
#   'possession'],
#  ('the', 'recess'): ['and'],
#  ('recess', 'and'): ['struck'],
#  ('and', 'struck'): ['matches'],
#  ('struck', 'matches'): ['on'],
#  ('matches', 'on'): ['the'],
#  ('the', 'panels'): ['children', 'crashed'],
#  ('panels', 'children'): ['kept'],
#  ('children', 'kept'): ['shop'],
#  ('kept', 'shop'): ['upon'],
#  ('shop', 'upon'): ['the'],
#  ('upon', 'the'): ['steps',
#   'other’s',
#   'roadway',
#   'victim',
#   'woman’s',
#   'walls',
#   'court',
#   'other',
#   'cover',
#   'doorstep',
#   'butler’s',
#   'name',
#   'nearest',
#   'air',
#   'court',
#   'carpet',
#   'reading',
#   'table',
#   'instant',
#   'subject',
#   'countenance',
#   'scaffold'],
#  ('the', 'steps'): ['the', 'drew', 'and', 'fell', 'of'],
#  ('steps', 'the'): ['schoolboy'],
#  ('the', 'schoolboy'): ['had'],
#  ('schoolboy', 'had'): ['tried'],
#  ('had', 'tried'): ['his'],
#  ('tried', 'his'): ['knife'],
#  ('his', 'knife'): ['on'],
#  ('knife', 'on'): ['the'],
#  ('the', 'mouldings'): ['and'],
#  ('mouldings', 'and'): ['for'],
#  ('and', 'for'): ['close', 'the', 'whom', 'your', 'more', 'the'],
#  ('for', 'close'): ['on', 'upon'],
#  ('close', 'on'): ['a'],
#  ('on', 'a'): ['generation', 'greatcoat', 'sheet', 'shelf', 'piece', 'bench'],
#  ('a', 'generation'): ['no'],
#  ('generation', 'no'): ['one'],
#  ('no', 'one'): ['had', 'on', 'protesting', 'has'],
#  ('one', 'had'): ['appeared'],
#  ('had', 'appeared'): ['to'],
#  ('appeared', 'to'): ['drive', 'hesitate'],
#  ('to', 'drive'): ['away', 'straight'],
#  ('drive', 'away'): ['these'],
#  ('away', 'these'): ['random'],
#  ('these', 'random'): ['visitors'],
#  ('random', 'visitors'): ['or'],
#  ('visitors', 'or'): ['to'],
#  ('or', 'to'): ['repair'],
#  ('to', 'repair'): ['their'],
#  ('repair', 'their'): ['ravages'],
#  ('their', 'ravages'): ['mr'],
#  ('ravages', 'mr'): ['enfield'],
#  ('mr', 'enfield'): ['and',
#   'i',
#   'yes',
#   'but',
#   'it',
#   'i',
#   'that',
#   'and',
#   'dr',
#   'up',
#   'only'],
#  ('enfield', 'and'): ['the', 'by', 'me'],
#  ('lawyer', 'were'): ['on'],
#  ('were', 'on'): ['the'],
#  ('the', 'other'): ['side',
#   'a',
#   'if',
#   'party',
#   'with',
#   'what',
#   'how',
#   'snarled',
#   'musingly',
#   'with',
#   'and',
#   'without',
#   'half',
#   'i',
#   'and',
#   'as',
#   'returned',
#   'i',
#   'we',
#   'ingredients',
#   'evil',
#   'was',
#   'side',
#   'day',
#   'side'],
#  ('other', 'side'): ['of', 'i', 'all'],
#  ('side', 'of'): ['the', 'the', 'the', 'the', 'his', 'my', 'man', 'me'],
#  ('the', 'by-street'): ['but',
#   'of',
#   'was',
#   'there',
#   'and',
#   'and',
#   'and',
#   'it'],
#  ('by-street', 'but'): ['when'],
#  ('but', 'when'): ['they', 'the', 'he', 'i'],
#  ('when', 'they'): ['came', 'had', 'came', 'got', 'entered'],
#  ('came', 'abreast'): ['of'],
#  ('abreast', 'of'): ['the'],
#  ('entry', 'the'): ['former'],
#  ('the', 'former'): ['lifted'],
#  ('former', 'lifted'): ['up'],
#  ('lifted', 'up'): ['his'],
#  ('up', 'his'): ['cane', 'candle'],
#  ('his', 'cane'): ['and'],
#  ('cane', 'and'): ['pointed', 'carrying'],
#  ('and', 'pointed'): ['did'],
#  ('pointed', 'did'): ['you'],
#  ('did', 'you'): ['ever',
#   'ever',
#   'know',
#   'know',
#   'compare',
#   'said',
#   'recognise'],
#  ('you', 'ever'): ['remark', 'come', 'met'],
#  ('ever', 'remark'): ['that'],
#  ('remark', 'that'): ['door', 'whereas'],
#  ('that', 'door'): ['he', 'ah'],
#  ('door', 'he'): ['asked'],
#  ('he', 'asked'): ['and', 'hyde', 'on', 'i', 'poole', 'i', 'he'],
#  ('asked', 'and'): ['when'],
#  ('when', 'his'): ['companion'],
#  ('his', 'companion'): ['had', 'they'],
#  ('companion', 'had'): ['replied'],
#  ('had', 'replied'): ['in'],
#  ('replied', 'in'): ['the'],
#  ('the', 'affirmative'): ['it'],
#  ('affirmative', 'it'): ['is'],
#  ('is', 'connected'): ['in'],
#  ('connected', 'in'): ['my'],
#  ('in', 'my'): ['mind',
#   'chambers',
#   'cab',
#   'hand',
#   'dining-room',
#   'extreme',
#   'name',
#   'house',
#   'customary',
#   'hand',
#   'faults',
#   'own',
#   'reflections',
#   'soul',
#   'sensations',
#   'fancy',
#   'room',
#   'new',
#   'own',
#   'eyes',
#   'second',
#   'impenetrable',
#   'disguise',
#   'psychological',
#   'breast',
#   'stature',
#   'career',
#   'lot',
#   'cabinet',
#   'soul',
#   'case',
#   'wake',
#   'future',
#   'own',
#   'second',
#   'hands',
#   'presence',
#   'own',
#   'soul',
#   'chair',
#   'own',
#   'own',
#   'heart',
#   'chair'],
#  ('my', 'mind'): ['added', 'misgives', 'if', 'submerged', 'to', 'that'],
#  ('mind', 'added'): ['he'],
#  ('added', 'he'): ['with'],
#  ('he', 'with'): ['a'],
#  ('with', 'a'): ['very',
#   'slight',
#   'strong',
#   'kind',
#   'name',
#   'really',
#   'touch',
#   'clouded',
#   'shock',
#   'strong',
#   'hissing',
#   'flush',
#   'sort',
#   'husky',
#   'very',
#   'certain',
#   'very',
#   'distasteful',
#   'cheval-glass',
#   'qualm',
#   'sound',
#   'note',
#   'small',
#   'purpose',
#   'smile',
#   'pale',
#   'red',
#   'ferocity',
#   'somewhat',
#   'note',
#   'sudden',
#   'pair',
#   'certain',
#   'loud',
#   'semblance',
#   'scare',
#   'startling',
#   'start',
#   'locksmith',
#   'case',
#   'smiling',
#   'keen',
#   'strong',
#   'load',
#   'signature',
#   'swart',
#   'darkened',
#   'greedy',
#   'transport',
#   'gust',
#   'great',
#   'stringent'],
#  ('a', 'very'): ['odd',
#   'good',
#   'heavy',
#   'strange',
#   'strange',
#   'great',
#   'great',
#   'pretty',
#   'popular',
#   'odd',
#   'interesting',
#   'guarded',
#   'strange'],
#  ('very', 'odd'): ['story', 'writer'],
#  ('odd', 'story'): ['indeed'],
#  ('story', 'indeed'): ['said'],
#  ('indeed', 'said'): ['mr', 'utterson', 'poole'],
#  ('said', 'mr'): ['utterson',
#   'utterson',
#   'enfield',
#   'utterson',
#   'utterson',
#   'enfield',
#   'utterson',
#   'utterson',
#   'utterson',
#   'utterson',
#   'utterson',
#   'utterson',
#   'utterson',
#   'utterson',
#   'utterson',
#   'utterson',
#   'utterson',
#   'utterson'],
#  ('utterson', 'with'): ['a', 'a'],
#  ('a', 'slight'): ['change'],
#  ('slight', 'change'): ['of'],
#  ('change', 'of'): ['voice', 'colour'],
#  ('of', 'voice'): ['and'],
#  ('voice', 'and'): ['what', 'now', 'now', 'taking'],
#  ('what', 'was'): ['that', 'in', 'in', 'rare', 'the', 'dead'],
#  ('was', 'that'): ['well', 'there', 'my', 'i', 'when', 'unknown'],
#  ('that', 'well'): ['it'],
#  ('was', 'this'): ['way', 'way', 'gentleman', 'to'],
#  ('this', 'way'): ['returned', 'i'],
#  ('way', 'returned'): ['mr'],
#  ('returned', 'mr'): ['enfield', 'enfield', 'hyde'],
#  ('enfield', 'i'): ['was', 'can’t'],
#  ('i', 'was'): ['coming',
#   'never',
#   'thinking',
#   'about',
#   'about',
#   'always',
#   'a',
#   'in',
#   'dealing',
#   'struck',
#   'far',
#   'born',
#   'guilty',
#   'and',
#   'driven',
#   'in',
#   'no',
#   'radically',
#   'so',
#   'conscious',
#   'suddenly',
#   'with',
#   'conscious',
#   'doubtless',
#   'not',
#   'the',
#   'the',
#   'often',
#   'not',
#   'that',
#   'accustomed',
#   'still',
#   'in',
#   'then',
#   'unable',
#   'able',
#   'led',
#   'slowly',
#   'true',
#   'punished',
#   'conscious',
#   'suddenly',
#   'now',
#   'glad',
#   'glad',
#   'still',
#   'once',
#   'not',
#   'like',
#   'once',
#   'the',
#   'once',
#   'stepping',
#   'seized',
#   'once',
#   'able'],
#  ('was', 'coming'): ['home'],
#  ('coming', 'home'): ['from'],
#  ('home', 'from'): ['some'],
#  ('from', 'some'): ['place'],
#  ('some', 'place'): ['at'],
#  ('place', 'at'): ['the'],
#  ('the', 'end'): ['of', 'of', 'is', 'it'],
#  ('end', 'of'): ['the', 'london', 'the', 'a', 'the', 'it', 'practical'],
#  ('the', 'world'): ['about', 'and', 'these', 'i', 'and'],
#  ('world', 'about'): ['three'],
#  ('about', 'three'): ['o’clock'],
#  ('three', 'o’clock'): ['of'],
#  ('o’clock', 'of'): ['a'],
#  ('a', 'black'): ['winter'],
#  ('black', 'winter'): ['morning'],
#  ('winter', 'morning'): ['and'],
#  ('morning', 'and'): ['my', 'come', 'the'],
#  ('and', 'my'): ['way', 'hand', 'impatience', 'soul', 'spirits', 'punishment'],
#  ('my', 'way'): ['lay', 'into'],
#  ('way', 'lay'): ['through', 'once'],
#  ('lay', 'through'): ['a'],
#  ('through', 'a'): ['part'],
#  ('a', 'part'): ['of', 'instead'],
#  ('part', 'of'): ['town',
#   'the',
#   'it',
#   'the',
#   'his',
#   'london',
#   'the',
#   'the',
#   'me',
#   'my',
#   'his'],
#  ('of', 'town'): ['where'],
#  ('town', 'where'): ['there'],
#  ('where', 'there'): ['was', 'was'],
#  ('there', 'was'): ['literally',
#   'already',
#   'one',
#   'the',
#   'something',
#   'a',
#   'a',
#   'nothing',
#   'a',
#   'no',
#   'a',
#   'another',
#   'an',
#   'borne',
#   'full',
#   'murder',
#   'something',
#   'a',
#   'never',
#   'a',
#   'something',
#   'added',
#   'something',
#   'no',
#   'still'],
#  ('was', 'literally'): ['nothing'],
#  ('literally', 'nothing'): ['to'],
#  ('nothing', 'to'): ['be', 'hear', 'do'],
#  ('be', 'seen'): ['but', 'if'],
#  ('seen', 'but'): ['lamps'],
#  ('but', 'lamps'): ['street'],
#  ('lamps', 'street'): ['after'],
#  ('street', 'after'): ['street', 'street'],
#  ('after', 'street'): ['and', 'all'],
#  ('street', 'and'): ['all'],
#  ('all', 'the'): ['folks',
#   'time',
#   'corners',
#   'more',
#   'way',
#   'hurry',
#   'wholesale',
#   'circumstances'],
#  ('the', 'folks'): ['asleep'],
#  ('folks', 'asleep'): ['street'],
#  ('asleep', 'street'): ['after'],
#  ('street', 'all'): ['lighted'],
#  ('all', 'lighted'): ['up'],
#  ('lighted', 'up'): ['as', 'with', 'the', 'from'],
#  ('up', 'as'): ['if'],
#  ('as', 'if'): ['for',
#   'upon',
#   'the',
#   'he',
#   'with',
#   'he',
#   'the',
#   'to',
#   'a',
#   'with',
#   'out'],
#  ('if', 'for'): ['a'],
#  ('for', 'a'): ['procession',
#   'while',
#   'few',
#   'moment',
#   'thousand',
#   'moment',
#   'murderer',
#   'glimpse',
#   'locksmith',
#   'mere',
#   'moment',
#   'fresh'],
#  ('a', 'procession'): ['and'],
#  ('procession', 'and'): ['all'],
#  ('all', 'as'): ['empty'],
#  ('as', 'empty'): ['as'],
#  ('empty', 'as'): ['a'],
#  ('as', 'a'): ['church',
#   'bagpipe',
#   'lawyer',
#   'lover',
#   'ballroom',
#   'public',
#   'look',
#   'disloyalty',
#   'testament',
#   'deed',
#   'disgustful',
#   'kind',
#   'beloved',
#   'wind',
#   'housekeeper',
#   'whole'],
#  ('a', 'church'): ['till'],
#  ('church', 'till'): ['at'],
#  ('till', 'at'): ['last'],
#  ('at', 'last'): ['i',
#   'he',
#   'my',
#   'his',
#   'getting',
#   'received',
#   'let',
#   'returning',
#   'turned',
#   'i',
#   'overcame',
#   'in',
#   'to',
#   'in',
#   'fell',
#   'and',
#   'thinking'],
#  ('last', 'i'): ['got', 'think', 'had'],
#  ('i', 'got'): ['into'],
#  ('got', 'into'): ['that', 'a', 'bed'],
#  ('into', 'that'): ['state', 'house', 'deep'],
#  ('that', 'state'): ['of'],
#  ('state', 'of'): ['mind', 'my'],
#  ('of', 'mind'): ['when', 'and', 'i', 'gloating'],
#  ('mind', 'when'): ['a'],
#  ('when', 'a'): ['man', 'new', 'fresh', 'drunkard'],
#  ('man', 'listens'): ['and'],
#  ('listens', 'and'): ['listens', 'begins'],
#  ('and', 'listens'): ['and'],
#  ('and', 'begins'): ['to'],
#  ('begins', 'to'): ['long'],
#  ('to', 'long'): ['for'],
#  ('long', 'for'): ['the'],
#  ('for', 'the'): ['sight',
#   'man',
#   'child’s',
#   'balance',
#   'buildings',
#   'startling',
#   'door',
#   'most',
#   'fanlight',
#   'last',
#   'police',
#   'retail',
#   'old',
#   'death',
#   'last',
#   'hands',
#   'window',
#   'worse',
#   'moment',
#   'cabinet',
#   'glazed',
#   'police',
#   'second',
#   'moral',
#   'very',
#   'conception',
#   'first',
#   'complete',
#   'steps',
#   'pangs',
#   'last'],
#  ('the', 'sight'): ['of', 'of', 'i', 'that'],
#  ('sight', 'of'): ['a', 'mr', 'mr', 'the'],
#  ('a', 'policeman'): ['all', 'not'],
#  ('policeman', 'all'): ['at'],
#  ('all', 'at'): ['once', 'an', 'the', 'your'],
#  ('at', 'once'): ['i',
#   'admitted',
#   'and',
#   'so',
#   'to',
#   'and',
#   'expense',
#   'on',
#   'for',
#   'from',
#   'the',
#   'glorying'],
#  ('once', 'i'): ['saw', 'heard', 'had'],
#  ('i', 'saw'): ['two',
#   'that',
#   'him',
#   'mr',
#   'him',
#   'him',
#   'what',
#   'i',
#   'that',
#   'for',
#   'the',
#   'my',
#   'my',
#   'i'],
#  ('saw', 'two'): ['figures'],
#  ('two', 'figures'): ['one'],
#  ('figures', 'one'): ['a'],
#  ('one', 'a'): ['little'],
#  ('a', 'little'): ['man',
#   'rambling',
#   'hoarsely',
#   'looking',
#   'and',
#   'damp',
#   'closer',
#   'and',
#   'drowsed'],
#  ('little', 'man'): ['who'],
#  ('man', 'who'): ['was', 'walked', 'was', 'was', 'will', 'could'],
#  ('who', 'was'): ['stumping',
#   'running',
#   'without',
#   'heir',
#   'much',
#   'jekyll’s',
#   'composite'],
#  ('was', 'stumping'): ['along'],
#  ('stumping', 'along'): ['eastward'],
#  ('along', 'eastward'): ['at'],
#  ('eastward', 'at'): ['a'],
#  ('at', 'a'): ['good', 'loss', 'nicely', 'late', 'blow'],
#  ('a', 'good'): ['walk', 'rule', 'fellow', 'picture', 'deal', 'fire', 'deal'],
#  ('good', 'walk'): ['and'],
#  ('walk', 'and'): ['the'],
#  ('other', 'a'): ['girl'],
#  ('a', 'girl'): ['of'],
#  ('girl', 'of'): ['maybe'],
#  ('of', 'maybe'): ['eight'],
#  ('maybe', 'eight'): ['or'],
#  ('eight', 'or'): ['ten'],
#  ('or', 'ten'): ['who'],
#  ('ten', 'who'): ['was'],
#  ('was', 'running'): ['as'],
#  ('running', 'as'): ['hard'],
#  ('as', 'hard'): ['as'],
#  ('hard', 'as'): ['she'],
#  ('as', 'she'): ['was', 'so'],
#  ('she', 'was'): ['able', 'romantically', 'surprised'],
#  ('was', 'able'): ['down', 'in', 'to'],
#  ('able', 'down'): ['a'],
#  ('a', 'cross'): ['street'],
#  ('cross', 'street'): ['well'],
#  ('street', 'well'): ['sir'],
#  ('well', 'sir'): ['the', 'he', 'returned', 'he', 'every', 'it'],
#  ('sir', 'the'): ['two'],
#  ('two', 'ran'): ['into'],
#  ('ran', 'into'): ['one'],
#  ('into', 'one'): ['another'],
#  ('one', 'another'): ['naturally'],
#  ('another', 'naturally'): ['enough'],
#  ('naturally', 'enough'): ['at'],
#  ('enough', 'at'): ['the'],
#  ('the', 'corner'): ['and', 'from', 'was', 'with', 'of'],
#  ('corner', 'and'): ['then'],
#  ('and', 'then'): ['came',
#   'there',
#   'enfield',
#   'approached',
#   'these',
#   'the',
#   'suddenly',
#   'as',
#   'by',
#   'all',
#   'raising',
#   'after',
#   'he',
#   'taking',
#   'he',
#   'sharply',
#   'with',
#   'the',
#   'who',
#   'conquering',
#   'back',
#   'why',
#   'paused',
#   'turned',
#   'with',
#   'with',
#   'i',
#   'as'],
#  ('then', 'came'): ['the'],
#  ('came', 'the'): ['horrible', 'news'],
#  ('the', 'horrible'): ['part'],
#  ('horrible', 'part'): ['of'],
#  ('the', 'thing'): ['for', 'that'],
#  ('thing', 'for'): ['the'],
#  ('the', 'man'): ['trampled',
#   'we',
#   'in',
#   'was',
#   'such',
#   'seems',
#   'and',
#   'we',
#   'of',
#   'hyde',
#   'there',
#   'mean',
#   'at',
#   'paused',
#   'dined'],
#  ('man', 'trampled'): ['calmly'],
#  ('trampled', 'calmly'): ['over'],
#  ('calmly', 'over'): ['the'],
#  ('over', 'the'): ['child’s', 'child', 'city', 'laboratory', 'moon', 'fire'],
#  ('the', 'child’s'): ['body', 'family', 'family', 'father', 'family'],
#  ('child’s', 'body'): ['and'],
#  ('body', 'and'): ['left', 'mind'],
#  ('and', 'left'): ['her', 'the', 'me'],
#  ('left', 'her'): ['screaming'],
#  ('her', 'screaming'): ['on', 'and'],
#  ('screaming', 'on'): ['the'],
#  ('the', 'ground'): ['it', 'the'],
#  ('ground', 'it'): ['sounds'],
#  ('it', 'sounds'): ['nothing'],
#  ('sounds', 'nothing'): ['to'],
#  ('to', 'hear'): ['but', 'more', 'of', 'your', 'and', 'more'],
#  ('hear', 'but'): ['it'],
#  ('was', 'hellish'): ['to'],
#  ('hellish', 'to'): ['see'],
#  ('to', 'see'): ['it',
#   'he',
#   'it',
#   'more',
#   'his',
#   'it',
#   'his',
#   'or',
#   'you',
#   'and',
#   'you',
#   'daylight',
#   'you',
#   'you',
#   'himself',
#   'that'],
#  ('see', 'it'): ['wasn’t', 'glide', 'one', 'was'],
#  ('it', 'wasn’t'): ['like'],
#  ('wasn’t', 'like'): ['a'],
#  ('man', 'it'): ['was'],
#  ('was', 'like'): ['some', 'the', 'my'],
#  ('like', 'some'): ['damned', 'disconsolate'],
#  ('some', 'damned'): ['juggernaut'],
#  ('damned', 'juggernaut'): ['i'],
#  ('juggernaut', 'i'): ['gave'],
#  ('i', 'gave'): ['a', 'in'],
#  ('gave', 'a'): ['few', 'number', 'jerk', 'kind', 'man'],
#  ('a', 'few'): ['halloa',
#   'small',
#   'seconds',
#   'seconds',
#   'dark',
#   'seconds',
#   'minims'],
#  ('few', 'halloa'): ['took'],
#  ('halloa', 'took'): ['to'],
#  ('took', 'to'): ['my', 'his'],
#  ('to', 'my'): ['heels',
#   'gentleman',
#   'gentleman',
#   'house',
#   'interest',
#   'politeness',
#   'feet',
#   'original',
#   'bedroom',
#   'room',
#   'cabinet',
#   'servants',
#   'determination',
#   'evil',
#   'own',
#   'drugs'],
#  ('my', 'heels'): ['collared'],
#  ('heels', 'collared'): ['my'],
#  ('collared', 'my'): ['gentleman'],
#  ('my', 'gentleman'): ['and', 'at', 'that'],
#  ('gentleman', 'and'): ['brought'],
#  ('and', 'brought'): ['him', 'me'],
#  ('brought', 'him'): ['back', 'a'],
#  ('him', 'back'): ['to', 'conscious'],
#  ('back', 'to'): ['where', 'me', 'the', 'his', 'my'],
#  ('to', 'where'): ['there', 'that'],
#  ('was', 'already'): ['quite', 'bad', 'fairly'],
#  ('already', 'quite'): ['a'],
#  ('quite', 'a'): ['group'],
#  ('a', 'group'): ['about'],
#  ('group', 'about'): ['the'],
#  ('about', 'the'): ['screaming',
#   'lot',
#   'place',
#   'court',
#   'floor',
#   'house',
#   'hearth',
#   'fire',
#   'streets'],
#  ('the', 'screaming'): ['child'],
#  ('screaming', 'child'): ['he'],
#  ('child', 'he'): ['was'],
#  ('was', 'perfectly'): ['cool'],
#  ('perfectly', 'cool'): ['and'],
#  ('cool', 'and'): ['made', 'a'],
#  ('and', 'made'): ['no', 'greater', 'myself'],
#  ('made', 'no'): ['resistance'],
#  ('no', 'resistance'): ['but'],
#  ('resistance', 'but'): ['gave'],
#  ('but', 'gave'): ['me'],
#  ('gave', 'me'): ['one'],
#  ('me', 'one'): ['look'],
#  ('one', 'look'): ['so'],
#  ('look', 'so'): ['ugly'],
#  ('so', 'ugly'): ['that'],
#  ('ugly', 'that'): ['it'],
#  ('that', 'it'): ['brought', 'was', 'might', 'will', 'was', 'almost', 'was'],
#  ('it', 'brought'): ['out', 'on'],
#  ('brought', 'out'): ['the'],
#  ('the', 'sweat'): ['on'],
#  ('sweat', 'on'): ['me'],
#  ('on', 'me'): ['like'],
#  ('me', 'like'): ['running', 'so', 'wine'],
#  ('like', 'running'): ['the'],
#  ('running', 'the'): ['people'],
#  ('the', 'people'): ['who'],
#  ('people', 'who'): ['had'],
#  ('who', 'had'): ['turned', 'once', 'kept', 'thus', 'watched'],
#  ...}

# %% [markdown]
# You can use the following loop to test your function with the words from the book.

# %%
successor_map = {}
window = []

for line in open(filename):
    for word in split_line(line):
        word = clean_word(word)
        process_word_trigram(word)

# %% [markdown]
# In the next exercise, you'll use the results to generate new random text.

# %% [markdown]
# ### Exercise
#
# For this exercise, we'll assume that `successor_map` is a dictionary that maps from each bigram to the list of words that follow it.

# %%
# this cell initializes the random number generator so it
# starts at the same point in the sequence each time this
# notebook runs.

random.seed(3)

# %% [markdown]
# To generate random text, we'll start by choosing a random key from `successor_map`.

# %%
successors = list(successor_map)
bigram = random.choice(successors)
bigram
# Out:
# ('one', 'lay')

# %% [markdown]
# Now write a loop that generates 50 more words following these steps:
#
# 1. In `successor_map`, look up the list of words that can follow `bigram`.
#
# 2. Choose one of them at random and print it.
#
# 3. For the next iteration, make a new bigram that contains the second word from `bigram` and the chosen successor.
#
# For example, if we start with the bigram `('doubted', 'if')` and choose `'from'` as its successor, the next bigram is `('if', 'from')`.

# %%
def bigram_gen(current_bigram):
    sentence = list(current_bigram)
    for i in range(50):
        if current_bigram in successor_map:
            possible_successors = successor_map[current_bigram]
            next_word = random.choice(possible_successors)
            sentence.append(next_word)
            current_bigram = (current_bigram[1], next_word)
        else:
            break
    sentence = " ".join(sentence)

    return sentence

bigram_gen(bigram)
# Out:
# 'one lay beside the tea things stood ready to be re-administered in short from that day forth it seemed to have been wanting to speak of it i shall die incredulous as for the conception of the spirit that cannot be exceeded at the last time short of a person but he'

# %% [markdown]
# If everything is working, you should find that the generated text is recognizably similar in style to the original, and some phrases make sense, but the text might wander from one topic to another.
#
# As a bonus exercise, modify your solution to the last two exercises to use trigrams as keys in `successor_map`, and see what effect it has on the results.

# %% [markdown]
# [Think Python: 3rd Edition](https://allendowney.github.io/ThinkPython/index.html)
#
# Copyright 2024 [Allen B. Downey](https://allendowney.com)
#
# Code license: [MIT License](https://mit-license.org/)
#
# Text license: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
